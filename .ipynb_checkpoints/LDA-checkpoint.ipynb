# %%
import os
import json
from keras.preprocessing.text import Tokenizer
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
english_stemmer=nltk.stem.SnowballStemmer('english')
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation, PCA
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import random
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import silhouette_score
from nltk.tokenize import RegexpTokenizer
import gensim
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from gensim import models
from gensim.corpora import Dictionary
from gensim.models import ldamodel
from gensim.models import Doc2Vec
from gensim.models import TfidfModel
# Out:
# /Users/shengyuan/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def load_data(dir,round,args):
    data = []
    data_args = []
    for i in range(1,6):
        with open(os.path.join(dir,'r%d/%d.json'%(round,i)),'r') as d:
            tem_data = json.load(d)
        data.extend(tem_data['result']['docs'])
    for i in range(len(data)):
        data_args.append(data[i][args])
        data_args = list(set(data_args))
    return data_args

# %%
#Data cleaning
def text_cleaning(text):
    myText = text.lower()    
    # clean and tokenize document string
    stop_words = set(stopwords.words('english'))
    document_content = myText.split()    
    word_list = []
    for i in document_content:
        x = 0
        if (('cent' not in i) and('ms' not in i) and ('per' not in i) and ('yal' not in i)  and ('mr' not in i)  and ('commission' not in i) and  ('http' not in i) and ('@' not in i) and ('<.*?>' not in i) and i.isalnum() and (not i in stop_words)):
            word_list += [i]
        
    return word_list

# %%
def review_to_wordlist( review, remove_stopwords=True):
    # Function to convert a document to a sequence of words,
    # optionally removing stop words.  Returns a list of words.
    

    #
    # 2. Remove non-letters
    review_text = re.sub("[^a-zA-Z]"," ", review)
    #
    # 3. Convert words to lower case and split them
    words = review_text.lower().split()
    #
    # 4. Optionally remove stop words (True by default)
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        myStops=['royal','commission','ms','mr','per','cent','subsection']
        words = [w for w in words if not w in stops]
        words = [w for w in words if not w in myStops]
    b=[]
    stemmer = english_stemmer #PorterStemmer()
    for word in words:
        b.append(stemmer.stem(word))

    # 5. Return a list of words
    return words

# %%
# load the data
dir='/Users/shengyuan/Desktop/Study/CAPSTONE/RoyalCommission' #data fold path
args = 'content'  #data type
round=4

data = load_data(dir,round,args)
# Number of corpus
l=len(data)

# %%
all_content = []
for em in data:            
    #Pre-processing
    processed_content = review_to_wordlist(em)
    
    # add tokens to list
    all_content.append(processed_content)

# %%
# LDA
dictionary = Dictionary(all_content)
corpus = [dictionary.doc2bow(text) for text in all_content]
tfidf_model = TfidfModel(corpus)  # fit model
corpus_tfidf = tfidf_model[corpus]

# %%
np.random.seed(1) # setting random seed to get the same results each time.
n_topics=10
model = ldamodel.LdaModel(corpus_tfidf, id2word=dictionary, num_topics=n_topics,iterations=1000)
model.show_topics()
# Out:
# [(0,
#   '0.001*"cba" + 0.001*"banks" + 0.001*"mortgage" + 0.001*"loan" + 0.001*"bank" + 0.001*"sales" + 0.001*"home" + 0.001*"growth" + 0.001*"tax" + 0.001*"brokers"'),
#  (1,
#   '0.001*"c" + 0.001*"growth" + 0.001*"market" + 0.001*"anz" + 0.001*"katter" + 0.001*"dover" + 0.001*"prices" + 0.000*"smiths" + 0.000*"housing" + 0.000*"amp"'),
#  (2,
#   '0.001*"evans" + 0.001*"funeral" + 0.001*"hirst" + 0.001*"dixon" + 0.001*"aboriginal" + 0.000*"acbf" + 0.000*"advice" + 0.000*"parkinson" + 0.000*"asic" + 0.000*"walsh"'),
#  (3,
#   '0.001*"aboriginal" + 0.001*"acbf" + 0.001*"funeral" + 0.001*"indigenous" + 0.001*"walsh" + 0.001*"insurance" + 0.001*"anz" + 0.001*"steinberg" + 0.001*"said" + 0.001*"company"'),
#  (4,
#   '0.001*"anz" + 0.001*"banks" + 0.001*"bank" + 0.001*"landmark" + 0.001*"customers" + 0.001*"dover" + 0.001*"debt" + 0.001*"asic" + 0.001*"informal" + 0.001*"customer"'),
#  (5,
#   '0.001*"cba" + 0.001*"insurance" + 0.001*"wealth" + 0.001*"cattle" + 0.000*"smith" + 0.000*"heard" + 0.000*"management" + 0.000*"video" + 0.000*"bank" + 0.000*"funeral"'),
#  (6,
#   '0.001*"bankwest" + 0.001*"ruddy" + 0.001*"marika" + 0.001*"bank" + 0.001*"insurance" + 0.001*"subsections" + 0.001*"loan" + 0.001*"property" + 0.001*"growth" + 0.001*"anz"'),
#  (7,
#   '0.001*"anz" + 0.001*"ruddy" + 0.001*"insure" + 0.001*"funeral" + 0.001*"bank" + 0.001*"insurance" + 0.001*"aboriginal" + 0.001*"account" + 0.001*"orr" + 0.001*"let"'),
#  (8,
#   '0.001*"brokers" + 0.001*"rural" + 0.001*"commissions" + 0.001*"bank" + 0.001*"anz" + 0.001*"landmark" + 0.001*"loan" + 0.000*"customers" + 0.000*"satisfaction" + 0.000*"banks"'),
#  (9,
#   '0.003*"subsections" + 0.002*"show" + 0.001*"funeral" + 0.001*"text" + 0.001*"orr" + 0.001*"insurance" + 0.001*"aboriginal" + 0.001*"anz" + 0.001*"asic" + 0.001*"indigenous"')]

# %%
x=model.show_topics(num_topics=10, num_words=8,formatted=False)
topics_words = [(tp[0], [wd[0] for wd in tp[1]]) for tp in x]
print(topics_words)
# Out:
# [(0, ['cba', 'banks', 'mortgage', 'loan', 'bank', 'sales', 'home', 'growth']), (1, ['c', 'growth', 'market', 'anz', 'katter', 'dover', 'prices', 'smiths']), (2, ['evans', 'funeral', 'hirst', 'dixon', 'aboriginal', 'acbf', 'advice', 'parkinson']), (3, ['aboriginal', 'acbf', 'funeral', 'indigenous', 'walsh', 'insurance', 'anz', 'steinberg']), (4, ['anz', 'banks', 'bank', 'landmark', 'customers', 'dover', 'debt', 'asic']), (5, ['cba', 'insurance', 'wealth', 'cattle', 'smith', 'heard', 'management', 'video']), (6, ['bankwest', 'ruddy', 'marika', 'bank', 'insurance', 'subsections', 'loan', 'property']), (7, ['anz', 'ruddy', 'insure', 'funeral', 'bank', 'insurance', 'aboriginal', 'account']), (8, ['brokers', 'rural', 'commissions', 'bank', 'anz', 'landmark', 'loan', 'customers']), (9, ['subsections', 'show', 'funeral', 'text', 'orr', 'insurance', 'aboriginal', 'anz'])]

# %%
all_topics = model.get_document_topics(corpus, per_word_topics=True)
count=1;
content_list=[]
content_num=[]
topic_list=[]
prob_list=[]
tp_words=[]
for doc_topics, word_topics, phi_values in all_topics:
    print('Document ',count,'\n')
    print('Document topics:', doc_topics)
    
    for doc_prob in doc_topics:
        topic_list.append(doc_prob[0])
        prob_list.append(doc_prob[1])
        words=" ".join(topics_words[doc_prob[0]][1])
        tp_words.append(words)
        content_list.append(data[count-1])
        content_num.append(count-1);
    #print ('Word topics:', word_topics)
    #print ('Phi values:', phi_values)
    print(" ")
    print('-------------- \n')
    count=count+1
# Out:
# Document  1
#
# Document topics: [(6, 0.4675628), (7, 0.5299676)]
#
# --------------
#
# Document  2
#
# Document topics: [(0, 0.09698156), (3, 0.7333153), (6, 0.090112194), (7, 0.07539433)]
#
# --------------
#
# Document  3
#
# Document topics: [(1, 0.30349103), (3, 0.31852522), (6, 0.20862523), (9, 0.1671522)]
#
# --------------
#
# Document  4
#
# Document topics: [(0, 0.08441124), (6, 0.8239284), (9, 0.09011116)]
#
# --------------
#
# Document  5
#
# Document topics: [(7, 0.99567217)]
#
# --------------
#
# Document  6
#
# Document topics: [(7, 0.5909586), (9, 0.40687892)]
#
# --------------
#
# Document  7
#
# Document topics: [(4, 0.7877133), (6, 0.20749542)]
#
# --------------
#
# Document  8
#
# Document topics: [(0, 0.9953834)]
#
# --------------
#
# Document  9
#
# Document topics: [(0, 0.038667127), (2, 0.033496384), (3, 0.25328758), (4, 0.045194447), (7, 0.18427569), (9, 0.4437883)]
#
# --------------
#
# Document  10
#
# Document topics: [(0, 0.22332938), (4, 0.120347016), (6, 0.13907467), (8, 0.4379767), (9, 0.07684449)]
#
# --------------
#
# Document  11
#
# Document topics: [(0, 0.31090507), (6, 0.032019485), (7, 0.6539775)]
#
# --------------
#
# Document  12
#
# Document topics: [(0, 0.16429523), (4, 0.073606424), (6, 0.060155768), (7, 0.10233787), (8, 0.4885792), (9, 0.10989536)]
#
# --------------
#
# Document  13
#
# Document topics: [(0, 0.5279712), (6, 0.46834168)]
#
# --------------
#
# Document  14
#
# Document topics: [(0, 0.43567923), (5, 0.3713358), (6, 0.07065873), (9, 0.12012806)]
#
# --------------
#
# Document  15
#
# Document topics: [(3, 0.9749952)]
#
# --------------
#
# Document  16
#
# Document topics: [(6, 0.99485624)]
#
# --------------
#
# Document  17
#
# Document topics: [(0, 0.118568376), (9, 0.87675244)]
#
# --------------
#
# Document  18
#
# Document topics: [(0, 0.11194842), (6, 0.8841675)]
#
# --------------
#
# Document  19
#
# Document topics: [(0, 0.07400157), (1, 0.59741485), (3, 0.19558549), (6, 0.1316555)]
#
# --------------
#
# Document  20
#
# Document topics: [(0, 0.08376643), (4, 0.86903477), (9, 0.042767353)]
#
# --------------
#
# Document  21
#
# Document topics: [(4, 0.531417), (9, 0.46361303)]
#
# --------------
#
# Document  22
#
# Document topics: [(0, 0.100774154), (6, 0.13244542), (9, 0.757492)]
#
# --------------
#
# Document  23
#
# Document topics: [(0, 0.1431535), (1, 0.34319758), (4, 0.057483755), (5, 0.06483644), (6, 0.1470808), (9, 0.24307804)]
#
# --------------
#
# Document  24
#
# Document topics: [(0, 0.36805487), (4, 0.39155656), (9, 0.23872952)]
#
# --------------
#
# Document  25
#
# Document topics: [(0, 0.1118383), (4, 0.027597604), (6, 0.80533415), (7, 0.04177364), (9, 0.012601497)]
#
# --------------
#
# Document  26
#
# Document topics: [(0, 0.18464519), (5, 0.2680372), (6, 0.11364257), (8, 0.27628988), (9, 0.15570691)]
#
# --------------
#
# Document  27
#
# Document topics: [(3, 0.8742209), (9, 0.12220701)]
#
# --------------
#
# Document  28
#
# Document topics: [(0, 0.12279458), (3, 0.12489073), (6, 0.19667353), (7, 0.037710518), (8, 0.40276355), (9, 0.11476455)]
#
# --------------
#
# Document  29
#
# Document topics: [(0, 0.09432074), (1, 0.745889), (6, 0.10603838), (9, 0.052406173)]
#
# --------------
#
# Document  30
#
# Document topics: [(4, 0.23505619), (6, 0.17975007), (7, 0.5074915), (9, 0.0759424)]
#
# --------------
#
# Document  31
#
# Document topics: [(4, 0.99108773)]
#
# --------------
#
# Document  32
#
# Document topics: [(0, 0.57397926), (6, 0.09555976), (7, 0.059228875), (9, 0.2674058)]
#
# --------------
#
# Document  33
#
# Document topics: [(7, 0.8320331), (9, 0.16542663)]
#
# --------------
#
# Document  34
#
# Document topics: [(9, 0.9942296)]
#
# --------------
#
# Document  35
#
# Document topics: [(6, 0.9812469)]
#
# --------------
#
# Document  36
#
# Document topics: [(0, 0.03257804), (1, 0.010528519), (3, 0.035227347), (6, 0.82964694), (7, 0.03974425), (9, 0.051916696)]
#
# --------------
#
# Document  37
#
# Document topics: [(0, 0.06733815), (1, 0.5624121), (6, 0.14822966), (7, 0.068379216), (9, 0.1527573)]
#
# --------------
#
# Document  38
#
# Document topics: [(0, 0.98043126)]
#
# --------------
#
# Document  39
#
# Document topics: [(0, 0.038510464), (3, 0.030378304), (6, 0.89631146), (9, 0.033008184)]
#
# --------------
#
# Document  40
#
# Document topics: [(0, 0.12113454), (3, 0.036246322), (6, 0.10548626), (7, 0.65686333), (9, 0.0799102)]
#
# --------------
#
# Document  41
#
# Document topics: [(0, 0.100444265), (3, 0.6291082), (6, 0.13884172), (7, 0.04807132), (9, 0.07576254)]
#
# --------------
#
# Document  42
#
# Document topics: [(4, 0.024451818), (6, 0.6470206), (7, 0.2201348), (9, 0.10717552)]
#
# --------------
#
# Document  43
#
# Document topics: [(9, 0.9357046)]
#
# --------------
#
# Document  44
#
# Document topics: [(0, 0.11979628), (4, 0.87653327)]
#
# --------------
#
# Document  45
#
# Document topics: [(6, 0.9867631)]
#
# --------------
#
# Document  46
#
# Document topics: [(0, 0.1686696), (4, 0.82281876)]
#
# --------------
#
# Document  47
#
# Document topics: [(0, 0.14777982), (4, 0.8488299)]
#
# --------------
#
# Document  48
#
# Document topics: [(6, 0.99716043)]
#
# --------------
#
# Document  49
#
# Document topics: [(0, 0.10723337), (3, 0.59550357), (4, 0.018156957), (6, 0.1845919), (7, 0.036634825), (9, 0.05743186)]
#
# --------------
#
# Document  50
#
# Document topics: [(6, 0.98831016)]
#
# --------------
#
# Document  51
#
# Document topics: [(5, 0.7499909), (7, 0.24441355)]
#
# --------------
#
# Document  52
#
# Document topics: [(0, 0.10301753), (3, 0.01946346), (4, 0.026585119), (6, 0.1530218), (7, 0.04229402), (8, 0.020529673), (9, 0.63496035)]
#
# --------------
#
# Document  53
#
# Document topics: [(9, 0.9933814)]
#
# --------------
#
# Document  54
#
# Document topics: [(0, 0.31620488), (6, 0.05967581), (7, 0.49890175), (8, 0.031037271), (9, 0.07718776)]
#
# --------------
#
# Document  55
#
# Document topics: [(3, 0.9763115)]
#
# --------------
#
# Document  56
#
# Document topics: [(0, 0.12546684), (3, 0.6162928), (4, 0.015106561), (6, 0.10784488), (7, 0.061817084), (9, 0.07305421)]
#
# --------------
#
# Document  57
#
# Document topics: [(3, 0.46095824), (4, 0.097988725), (7, 0.17320536), (9, 0.26463848)]
#
# --------------
#
# Document  58
#
# Document topics: [(0, 0.23672709), (1, 0.45034268), (7, 0.07836309), (9, 0.22964808)]
#
# --------------
#
# Document  59
#
# Document topics: [(6, 0.6896002), (7, 0.30854756)]
#
# --------------
#
# Document  60
#
# Document topics: [(0, 0.08044625), (4, 0.55326724), (6, 0.36479676)]
#
# --------------
#
# Document  61
#
# Document topics: [(6, 0.9955436)]
#
# --------------
#
# Document  62
#
# Document topics: [(1, 0.56930804), (7, 0.42127806)]
#
# --------------
#
# Document  63
#
# Document topics: [(0, 0.21516374), (3, 0.4854761), (6, 0.19583623), (9, 0.10278574)]
#
# --------------
#
# Document  64
#
# Document topics: [(0, 0.052162707), (6, 0.103452966), (7, 0.84175223)]
#
# --------------
#
# Document  65
#
# Document topics: [(6, 0.19266804), (7, 0.80344784)]
#
# --------------
#
# Document  66
#
# Document topics: [(4, 0.10389682), (6, 0.7684766), (7, 0.12516129)]
#
# --------------
#
# Document  67
#
# Document topics: [(6, 0.8208482), (7, 0.17430244)]
#
# --------------
#
# Document  68
#
# Document topics: [(0, 0.48886454), (1, 0.31891072), (6, 0.028874662), (7, 0.16099663)]
#
# --------------
#
# Document  69
#
# Document topics: [(0, 0.07340572), (4, 0.40057892), (6, 0.052717723), (7, 0.1702146), (9, 0.30190077)]
#
# --------------
#
# Document  70
#
# Document topics: [(0, 0.04917299), (6, 0.04734585), (7, 0.850876), (9, 0.051352303)]
#
# --------------
#
# Document  71
#
# Document topics: [(7, 0.9969484)]
#
# --------------
#
# Document  72
#
# Document topics: [(7, 0.7925702), (9, 0.20513046)]
#
# --------------
#
# Document  73
#
# Document topics: [(0, 0.1126411), (4, 0.8152985), (6, 0.06944804)]
#
# --------------
#
# Document  74
#
# Document topics: [(9, 0.993616)]
#
# --------------
#
# Document  75
#
# Document topics: [(0, 0.04206033), (3, 0.22818227), (6, 0.72289324)]
#
# --------------
#
# Document  76
#
# Document topics: [(0, 0.16794275), (5, 0.075484954), (6, 0.07639479), (7, 0.5458436), (9, 0.13326304)]
#
# --------------
#
# Document  77
#
# Document topics: [(4, 0.6286816), (7, 0.36625445)]
#
# --------------
#
# Document  78
#
# Document topics: [(0, 0.28274086), (4, 0.03752009), (6, 0.21844247), (7, 0.4600515)]
#
# --------------
#
# Document  79
#
# Document topics: [(0, 0.64739585), (4, 0.03083347), (6, 0.32049307)]
#
# --------------
#
# Document  80
#
# Document topics: [(6, 0.99608624)]
#
# --------------
#
# Document  81
#
# Document topics: [(0, 0.1487234), (6, 0.1616803), (7, 0.5189967), (8, 0.1691214)]
#
# --------------
#
# Document  82
#
# Document topics: [(0, 0.4958399), (9, 0.48062733)]
#
# --------------
#
# Document  83
#
# Document topics: [(7, 0.38848275), (9, 0.60917073)]
#
# --------------
#
# Document  84
#
# Document topics: [(0, 0.26023927), (9, 0.73667115)]
#
# --------------
#
# Document  85
#
# Document topics: [(4, 0.12855421), (9, 0.86885625)]
#
# --------------
#
# Document  86
#
# Document topics: [(6, 0.7954835), (7, 0.20187558)]
#
# --------------
#
# Document  87
#
# Document topics: [(0, 0.21234615), (4, 0.059509013), (5, 0.59817106), (9, 0.12845828)]
#
# --------------
#
# Document  88
#
# Document topics: [(3, 0.44512054), (6, 0.13065855), (7, 0.2680595), (9, 0.15386212)]
#
# --------------
#
# Document  89
#
# Document topics: [(0, 0.07730037), (4, 0.048248835), (9, 0.8721551)]
#
# --------------
#
# Document  90
#
# Document topics: [(0, 0.010001712), (1, 0.010000602), (2, 0.010001069), (3, 0.010002194), (4, 0.010001171), (5, 0.010001601), (6, 0.010002166), (7, 0.010003561), (8, 0.41475448), (9, 0.50523144)]
#
# --------------
#
# Document  91
#
# Document topics: [(0, 0.09438932), (6, 0.7743259), (9, 0.12924944)]
#
# --------------
#
# Document  92
#
# Document topics: [(0, 0.21103892), (6, 0.32917282), (7, 0.4578542)]
#
# --------------
#
# Document  93
#
# Document topics: [(7, 0.4793342), (8, 0.40457678), (9, 0.10675411)]
#
# --------------
#
# Document  94
#
# Document topics: [(0, 0.34823146), (6, 0.022236181), (7, 0.6276603)]
#
# --------------
#
# Document  95
#
# Document topics: [(0, 0.17007422), (1, 0.06956155), (6, 0.61643064), (7, 0.05920222), (9, 0.07745175)]
#
# --------------
#
# Document  96
#
# Document topics: [(9, 0.9955433)]
#
# --------------
#
# Document  97
#
# Document topics: [(3, 0.42822686), (6, 0.5354036)]
#
# --------------
#
# Document  98
#
# Document topics: [(0, 0.09846977), (2, 0.42760462), (3, 0.08152137), (6, 0.16232888), (7, 0.09341241), (9, 0.1358846)]
#
# --------------
#
# Document  99
#
# Document topics: [(0, 0.9566197), (9, 0.040522434)]
#
# --------------
#
# Document  100
#
# Document topics: [(8, 0.9399849)]
#
# --------------
#
# Document  101
#
# Document topics: [(0, 0.042865153), (6, 0.14499553), (7, 0.055595513), (8, 0.6325777), (9, 0.12237832)]
#
# --------------
#
# Document  102
#
# Document topics: [(6, 0.068351895), (7, 0.92821395)]
#
# --------------
#
# Document  103
#
# Document topics: [(0, 0.094863206), (3, 0.29874802), (4, 0.16287702), (7, 0.164467), (9, 0.27756077)]
#
# --------------
#
# Document  104
#
# Document topics: [(0, 0.11203491), (6, 0.14752297), (7, 0.6572619), (9, 0.08211616)]
#
# --------------
#
# Document  105
#
# Document topics: [(0, 0.9357063)]
#
# --------------
#
# Document  106
#
# Document topics: [(0, 0.8238784), (6, 0.08805471), (7, 0.048756164), (9, 0.03761543)]
#
# --------------
#
# Document  107
#
# Document topics: [(0, 0.27644637), (4, 0.16743624), (6, 0.1443522), (8, 0.41009352)]
#
# --------------
#
# Document  108
#
# Document topics: [(0, 0.19110309), (4, 0.46991184), (5, 0.026640583), (6, 0.06422093), (7, 0.12284781), (9, 0.1244609)]
#
# --------------
#
# Document  109
#
# Document topics: [(0, 0.13705322), (3, 0.3995906), (6, 0.45989016)]
#
# --------------
#
# Document  110
#
# Document topics: [(0, 0.40522492), (7, 0.52775437), (9, 0.060713124)]
#
# --------------
#
# Document  111
#
# Document topics: [(0, 0.13052057), (6, 0.44346225), (7, 0.42307553)]
#
# --------------
#
# Document  112
#
# Document topics: [(0, 0.3740067), (1, 0.19742294), (7, 0.41014546)]
#
# --------------
#
# Document  113
#
# Document topics: [(7, 0.9949427)]
#
# --------------
#
# Document  114
#
# Document topics: [(0, 0.011114116), (1, 0.0111124795), (2, 0.011111819), (3, 0.011112471), (4, 0.011113718), (5, 0.011112342), (6, 0.011114607), (7, 0.011114076), (8, 0.8999801), (9, 0.011114296)]
#
# --------------
#
# Document  115
#
# Document topics: [(7, 0.96666175)]
#
# --------------
#
# Document  116
#
# Document topics: [(3, 0.2382118), (5, 0.111761115), (6, 0.43815342), (7, 0.075671986), (9, 0.13436311)]
#
# --------------
#
# Document  117
#
# Document topics: [(2, 0.63952076), (6, 0.18065989), (9, 0.17663677)]
#
# --------------
#
# Document  118
#
# Document topics: [(0, 0.5558797), (4, 0.2816999), (7, 0.09696084), (9, 0.06416053)]
#
# --------------
#
# Document  119
#
# Document topics: [(0, 0.05446501), (6, 0.09623901), (7, 0.036864232), (9, 0.8114094)]
#
# --------------
#
# Document  120
#
# Document topics: [(7, 0.19200137), (9, 0.7879954)]
#
# --------------
#
# Document  121
#
# Document topics: [(0, 0.090142734), (7, 0.059452523), (9, 0.84848654)]
#
# --------------
#
# Document  122
#
# Document topics: [(0, 0.18361978), (5, 0.08755068), (6, 0.05889795), (7, 0.5403989), (9, 0.12843114)]
#
# --------------
#
# Document  123
#
# Document topics: [(0, 0.1173525), (1, 0.34843025), (3, 0.037704255), (4, 0.024468562), (6, 0.18996634), (7, 0.04115508), (9, 0.23279756)]
#
# --------------
#
# Document  124
#
# Document topics: [(0, 0.11165448), (6, 0.8854252)]
#
# --------------
#
# Document  125
#
# Document topics: [(1, 0.31660774), (4, 0.67977154)]
#
# --------------
#
# Document  126
#
# Document topics: [(3, 0.84373766), (6, 0.15400198)]
#
# --------------
#
# Document  127
#
# Document topics: [(0, 0.9418142), (9, 0.05543607)]
#
# --------------
#
# Document  128
#
# Document topics: [(8, 0.93998426)]
#
# --------------
#
# Document  129
#
# Document topics: [(0, 0.40448385), (1, 0.115427956), (2, 0.11240584), (4, 0.045719516), (6, 0.13825467), (7, 0.12038897), (9, 0.06265536)]
#
# --------------
#
# Document  130
#
# Document topics: [(7, 0.99664116)]
#
# --------------
#
# Document  131
#
# Document topics: [(0, 0.031749137), (9, 0.96628964)]
#
# --------------
#
# Document  132
#
# Document topics: [(0, 0.05680651), (1, 0.080223545), (4, 0.01485284), (5, 0.21138597), (6, 0.19872871), (7, 0.32915902), (9, 0.10297411)]
#
# --------------
#
# Document  133
#
# Document topics: [(0, 0.086516865), (6, 0.7811083), (9, 0.13123445)]
#
# --------------
#
# Document  134
#
# Document topics: [(5, 0.83108264), (9, 0.16437098)]
#
# --------------
#
# Document  135
#
# Document topics: [(0, 0.023312025), (6, 0.02972852), (9, 0.9446715)]
#
# --------------
#
# Document  136
#
# Document topics: [(0, 0.22537076), (1, 0.77108866)]
#
# --------------
#
# Document  137
#
# Document topics: [(0, 0.10004977), (3, 0.0119891325), (4, 0.037206), (6, 0.22146642), (8, 0.5176329), (9, 0.11095988)]
#
# --------------
#
# Document  138
#
# Document topics: [(1, 0.2500744), (4, 0.7456003)]
#
# --------------
#
# Document  139
#
# Document topics: [(0, 0.8290669), (7, 0.1451224)]
#
# --------------
#
# Document  140
#
# Document topics: [(0, 0.14977656), (2, 0.34691682), (6, 0.29093102), (9, 0.20924988)]
#
# --------------
#
# Document  141
#
# Document topics: [(4, 0.31790823), (6, 0.6358778), (9, 0.044589415)]
#
# --------------
#
# Document  142
#
# Document topics: [(0, 0.41855618), (2, 0.25463423), (7, 0.24328043), (9, 0.0783106)]
#
# --------------
#
# Document  143
#
# Document topics: [(0, 0.20143726), (3, 0.086838424), (4, 0.5734274), (6, 0.06386441), (8, 0.07307346)]
#
# --------------
#
# Document  144
#
# Document topics: [(0, 0.032581285), (1, 0.046620943), (4, 0.6088969), (6, 0.14521779), (9, 0.16557178)]
#
# --------------
#
# Document  145
#
# Document topics: [(7, 0.5208867), (8, 0.036792282), (9, 0.440544)]
#
# --------------
#
# Document  146
#
# Document topics: [(0, 0.9965377)]
#
# --------------
#
# Document  147
#
# Document topics: [(0, 0.7098346), (3, 0.073174775), (6, 0.12653051), (7, 0.0540456), (9, 0.028354943)]
#
# --------------
#
# Document  148
#
# Document topics: [(0, 0.033532593), (3, 0.21185762), (5, 0.044211928), (6, 0.33350617), (7, 0.15100989), (9, 0.22486116)]
#
# --------------
#
# Document  149
#
# Document topics: [(0, 0.40977386), (3, 0.015563777), (6, 0.4669001), (7, 0.036172964), (9, 0.07128281)]
#
# --------------
#
# Document  150
#
# Document topics: [(0, 0.8578759), (4, 0.09197423), (9, 0.03854582)]
#
# --------------
#
# Document  151
#
# Document topics: [(6, 0.99543047)]
#
# --------------
#
# Document  152
#
# Document topics: [(4, 0.85664284), (7, 0.064114474), (9, 0.07643086)]
#
# --------------
#
# Document  153
#
# Document topics: [(0, 0.19186784), (1, 0.29639444), (6, 0.17252475), (7, 0.2218793), (9, 0.115992896)]
#
# --------------
#
# Document  154
#
# Document topics: [(6, 0.088166766), (7, 0.43477273), (9, 0.4714594)]
#
# --------------
#
# Document  155
#
# Document topics: [(2, 0.73330194), (9, 0.23190922)]
#
# --------------
#
# Document  156
#
# Document topics: [(0, 0.47039494), (6, 0.44505647), (7, 0.03709802), (9, 0.04224998)]
#
# --------------
#
# Document  157
#
# Document topics: [(0, 0.80676776), (6, 0.07868758), (9, 0.11246702)]
#
# --------------
#
# Document  158
#
# Document topics: [(6, 0.078553125), (9, 0.9189772)]
#
# --------------
# Document  159
#
# Document topics: [(0, 0.3754987), (4, 0.07071041), (5, 0.34755254), (6, 0.07076142), (9, 0.13380988)]
#
# --------------
#
# Document  160
#
# Document topics: [(0, 0.2934013), (3, 0.46161976), (4, 0.044057086), (6, 0.15047288), (9, 0.04969461)]
#
# --------------
#
# Document  161
#
# Document topics: [(0, 0.98815626)]
#
# --------------
#
# Document  162
#
# Document topics: [(0, 0.41883484), (3, 0.35679767), (4, 0.052759), (6, 0.15304133), (7, 0.017445747)]
#
# --------------
#
# Document  163
#
# Document topics: [(7, 0.75827837), (9, 0.23904552)]
#
# --------------
#
# Document  164
#
# Document topics: [(1, 0.44100082), (4, 0.20053875), (6, 0.17046484), (9, 0.18376946)]
#
# --------------
#
# Document  165
#
# Document topics: [(5, 0.7476595), (9, 0.2464998)]
#
# --------------
#
# Document  166
#
# Document topics: [(4, 0.015522385), (6, 0.72657716), (7, 0.25595564)]
#
# --------------
#
# Document  167
#
# Document topics: [(0, 0.25369197), (1, 0.6426238), (6, 0.07452328), (9, 0.02782434)]
#
# --------------
#
# Document  168
#
# Document topics: [(6, 0.10788986), (7, 0.45877376), (9, 0.43160754)]
#
# --------------
#
# Document  169
#
# Document topics: [(3, 0.5803523), (7, 0.32451084), (9, 0.08987267)]
#
# --------------
#
# Document  170
#
# Document topics: [(0, 0.16884229), (3, 0.5560426), (6, 0.08251632), (7, 0.051438555), (9, 0.14019106)]
#
# --------------
#
# Document  171
#
# Document topics: [(0, 0.2333007), (6, 0.7647381)]
#
# --------------
#
# Document  172
#
# Document topics: [(5, 0.04486417), (6, 0.13705464), (7, 0.5102282), (9, 0.30687076)]
#
# --------------
#
# Document  173
#
# Document topics: [(0, 0.64737934), (4, 0.03084834), (6, 0.32049468)]
#
# --------------
#
# Document  174
#
# Document topics: [(6, 0.12960762), (7, 0.8677163)]
#
# --------------
#
# Document  175
#
# Document topics: [(0, 0.12098554), (6, 0.23869455), (8, 0.5911662), (9, 0.04646244)]
#
# --------------
#
# Document  176
#
# Document topics: [(7, 0.94374424)]
#
# --------------
#
# Document  177
#
# Document topics: [(0, 0.05978478), (5, 0.5084648), (6, 0.20054036), (7, 0.22785738)]
#
# --------------
#
# Document  178
#
# Document topics: [(0, 0.067729644), (6, 0.89022714), (9, 0.0399215)]
#
# --------------
#
# Document  179
#
# Document topics: [(0, 0.24554421), (1, 0.059658192), (4, 0.020925257), (5, 0.24100894), (6, 0.32005912), (7, 0.03566863), (9, 0.076653235)]
#
# --------------
#
# Document  180
#
# Document topics: [(7, 0.9967963)]
#
# --------------
#
# Document  181
#
# Document topics: [(6, 0.25551835), (7, 0.57257235), (9, 0.1573236)]
#
# --------------
#
# Document  182
#
# Document topics: [(0, 0.028636739), (1, 0.17764585), (4, 0.08051857), (5, 0.47432542), (7, 0.2377571)]
#
# --------------
#
# Document  183
#
# Document topics: [(0, 0.57736105), (4, 0.05770546), (7, 0.3622407)]
#
# --------------
#
# Document  184
#
# Document topics: [(0, 0.18243645), (3, 0.13253416), (4, 0.4200726), (6, 0.07067947), (7, 0.15858041), (9, 0.034430843)]
#
# --------------
#
# Document  185
#
# Document topics: [(9, 0.994155)]
#
# --------------
#
# Document  186
#
# Document topics: [(0, 0.86064017), (4, 0.060538597), (6, 0.04200116), (9, 0.035564624)]
#
# --------------
#
# Document  187
#
# Document topics: [(0, 0.49143797), (7, 0.48999462), (9, 0.015993392)]
#
# --------------
#
# Document  188
#
# Document topics: [(0, 0.98860514)]
#
# --------------
#
# Document  189
#
# Document topics: [(6, 0.13244344), (7, 0.7529858), (9, 0.11143116)]
#
# --------------
#
# Document  190
#
# Document topics: [(0, 0.34325254), (3, 0.35726032), (6, 0.29732612)]
#
# --------------
#
# Document  191
#
# Document topics: [(2, 0.8539656), (9, 0.12249923)]
#
# --------------
#
# Document  192
#
# Document topics: [(0, 0.12134263), (4, 0.4914269), (6, 0.21398808), (7, 0.09701512), (9, 0.074951366)]
#
# --------------
#
# Document  193
#
# Document topics: [(3, 0.71170694), (6, 0.10248563), (9, 0.18296126)]
#
# --------------
#
# Document  194
#
# Document topics: [(0, 0.07456068), (6, 0.9216651)]
#
# --------------
#
# Document  195
#
# Document topics: [(0, 0.31505382), (4, 0.59763026), (9, 0.08507172)]
#
# --------------
#
# Document  196
#
# Document topics: [(3, 0.8084026), (7, 0.17620976)]
#
# --------------
#
# Document  197
#
# Document topics: [(0, 0.23970169), (2, 0.25775596), (4, 0.026418548), (6, 0.085705936), (7, 0.23711276), (9, 0.15210721)]
#
# --------------
#
# Document  198
#
# Document topics: [(7, 0.0955131), (9, 0.90201724)]
#
# --------------
#
# Document  199
#
# Document topics: [(9, 0.9876694)]
#
# --------------
#
# Document  200
#
# Document topics: [(9, 0.99274045)]
#
# --------------
#
# Document  201
#
# Document topics: [(0, 0.04628828), (6, 0.8157466), (9, 0.13400951)]
#
# --------------
#
# Document  202
#
# Document topics: [(4, 0.19016573), (9, 0.8033291)]
#
# --------------
#
# Document  203
#
# Document topics: [(4, 0.1432485), (7, 0.53102803), (9, 0.32234094)]
#
# --------------
#
# Document  204
#
# Document topics: [(4, 0.6652574), (6, 0.14570627), (7, 0.09612219), (9, 0.09239223)]
#
# --------------
#
# Document  205
#
# Document topics: [(0, 0.062857896), (1, 0.37163907), (6, 0.08877499), (7, 0.47295365)]
#
# --------------
#
# Document  206
#
# Document topics: [(4, 0.2305597), (7, 0.56988245), (9, 0.1971924)]
#
# --------------
#
# Document  207
#
# Document topics: [(0, 0.06209799), (6, 0.36454844), (9, 0.5715537)]
#
# --------------
#
# Document  208
#
# Document topics: [(1, 0.18736313), (6, 0.14751214), (7, 0.52151173), (9, 0.14133114)]
#
# --------------
#
# Document  209
#
# Document topics: [(0, 0.02151885), (6, 0.14228366), (9, 0.8343353)]
#
# --------------
#
# Document  210
#
# Document topics: [(6, 0.59512913), (7, 0.4027083)]
#
# --------------
#
# Document  211
#
# Document topics: [(3, 0.07109135), (6, 0.6612248), (7, 0.06292653), (9, 0.20294976)]
#
# --------------
#
# Document  212
#
# Document topics: [(0, 0.09011216), (3, 0.024157701), (6, 0.09558861), (7, 0.0388786), (9, 0.750221)]
#
# --------------
#
# Document  213
#
# Document topics: [(0, 0.039566632), (7, 0.041432664), (8, 0.31732646), (9, 0.5987032)]
#
# --------------
#
# Document  214
#
# Document topics: [(0, 0.032451425), (4, 0.12259322), (6, 0.08749779), (7, 0.5330723), (8, 0.16798684), (9, 0.05559177)]
#
# --------------
#
# Document  215
#
# Document topics: [(0, 0.0664274), (4, 0.02436198), (6, 0.07360583), (7, 0.06645248), (9, 0.76824296)]
#
# --------------
#
# Document  216
#
# Document topics: [(0, 0.38703406), (5, 0.31039253), (6, 0.09735108), (9, 0.203849)]
#
# --------------
#
# Document  217
#
# Document topics: [(0, 0.9878352)]
#
# --------------
#
# Document  218
#
# Document topics: [(0, 0.43323648), (4, 0.48902282), (7, 0.07528406)]
#
# --------------
#
# Document  219
#
# Document topics: [(0, 0.23244314), (1, 0.4080168), (6, 0.18421935), (9, 0.17337848)]
#
# --------------
#
# Document  220
#
# Document topics: [(0, 0.70470846), (7, 0.29318026)]
#
# --------------
#
# Document  221
#
# Document topics: [(0, 0.15922584), (6, 0.15712649), (7, 0.08221946), (8, 0.5402746), (9, 0.060404874)]
#
# --------------
#
# Document  222
#
# Document topics: [(0, 0.22652133), (2, 0.14697337), (6, 0.106817506), (7, 0.39982155), (9, 0.118007034)]
#
# --------------
#
# Document  223
#
# Document topics: [(7, 0.9908145)]
#
# --------------
#
# Document  224
#
# Document topics: [(0, 0.37047988), (3, 0.09334189), (6, 0.43045375), (7, 0.018829571), (8, 0.021056294), (9, 0.06557003)]
#
# --------------
#
# Document  225
#
# Document topics: [(0, 0.98420864)]
#
# --------------
#
# Document  226
#
# Document topics: [(0, 0.2751592), (4, 0.025767554), (6, 0.22096336), (7, 0.055773694), (8, 0.21655269), (9, 0.20073168)]
#
# --------------
#
# Document  227
#
# Document topics: [(0, 0.0506164), (5, 0.26867756), (6, 0.50240606), (9, 0.17629959)]
#
# --------------
#
# Document  228
#
# Document topics: [(6, 0.035135604), (7, 0.021482565), (9, 0.9410244)]
#
# --------------
#
# Document  229
#
# Document topics: [(0, 0.12581821), (2, 0.25381446), (6, 0.18456738), (7, 0.2413752), (9, 0.19271784)]
#
# --------------
#
# Document  230
#
# Document topics: [(0, 0.13290168), (3, 0.63004464), (6, 0.07249932), (7, 0.08002151), (9, 0.08140718)]
#
# --------------
#
# Document  231
#
# Document topics: [(0, 0.16381039), (1, 0.4223238), (3, 0.039338723), (6, 0.18596397), (7, 0.020770838), (9, 0.16701236)]
#
# --------------
#
# Document  232
#
# Document topics: [(3, 0.6244367), (6, 0.149235), (7, 0.15597965), (9, 0.067377836)]
#
# --------------
#
# Document  233
#
# Document topics: [(9, 0.9943738)]
#
# --------------
#
# Document  234
#
# Document topics: [(0, 0.084206946), (6, 0.06091728), (9, 0.85373545)]
#
# --------------
#
# Document  235
#
# Document topics: [(2, 0.46460217), (9, 0.52955747)]
#
# --------------
#
# Document  236
#
# Document topics: [(0, 0.07106957), (2, 0.3895761), (6, 0.28058118), (7, 0.1355464), (9, 0.12140821)]
#
# --------------
#
# Document  237
#
# Document topics: [(0, 0.40042487), (2, 0.5066635), (9, 0.08821259)]
#
# --------------
#
# Document  238
#
# Document topics: [(0, 0.043552607), (3, 0.1178721), (4, 0.02013869), (6, 0.73492897), (9, 0.07261133)]
#
# --------------
#
# Document  239
#
# Document topics: [(0, 0.8896973), (4, 0.031944472), (9, 0.07526018)]
#
# --------------
#
# Document  240
#
# Document topics: [(1, 0.60341555), (7, 0.2138772), (9, 0.16270308)]
#
# --------------
#
# Document  241
#
# Document topics: [(0, 0.04305871), (6, 0.91625166), (9, 0.039144084)]
#
# --------------
#
# Document  242
#
# Document topics: [(6, 0.106370546), (7, 0.8898008)]
#
# --------------
#
# Document  243
#
# Document topics: [(0, 0.28294423), (3, 0.2107761), (6, 0.30434823), (7, 0.091792054), (9, 0.10742154)]
#
# --------------
#
# Document  244
#
# Document topics: [(0, 0.045865484), (4, 0.5072836), (6, 0.108066395), (9, 0.32980797)]
#
# --------------
#
# Document  245
#
# Document topics: [(6, 0.99338126)]
#
# --------------
#
# Document  246
#
# Document topics: [(0, 0.27542526), (9, 0.72111094)]
#
# --------------
#
# Document  247
#
# Document topics: [(2, 0.93075305)]
#
# --------------
#
# Document  248
#
# Document topics: [(0, 0.78202176), (4, 0.01401895), (6, 0.05486567), (7, 0.0718715), (9, 0.076423235)]
#
# --------------
#
# Document  249
#
# Document topics: [(0, 0.4101275), (1, 0.51071924), (6, 0.07616115)]
#
# --------------
#
# Document  250
#
# Document topics: [(0, 0.12009328), (6, 0.10044044), (9, 0.77808523)]
#
# --------------
#
# Document  251
#
# Document topics: [(0, 0.077045456), (6, 0.8090912), (7, 0.109487735)]
#
# --------------
#
# Document  252
#
# Document topics: [(0, 0.031605646), (4, 0.11886866), (7, 0.6431976), (9, 0.20487851)]
#
# --------------
#
# Document  253
#
# Document topics: [(0, 0.077511095), (9, 0.92118144)]
#
# --------------
#
# Document  254
#
# Document topics: [(0, 0.029403452), (3, 0.73688245), (6, 0.17228512), (9, 0.06060237)]
#
# --------------
#
# Document  255
#
# Document topics: [(0, 0.14649397), (4, 0.029276688), (6, 0.2421917), (8, 0.508651), (9, 0.07263344)]
#
# --------------
#
# Document  256
#
# Document topics: [(9, 0.9795425)]
#
# --------------
#
# Document  257
#
# Document topics: [(6, 0.035307158), (7, 0.96206933)]
#
# --------------
#
# Document  258
#
# Document topics: [(6, 0.947414), (7, 0.049728345)]
#
# --------------
#
# Document  259
#
# Document topics: [(3, 0.022155592), (6, 0.41789478), (7, 0.55694467)]
#
# --------------
#
# Document  260
#
# Document topics: [(4, 0.0499828), (9, 0.9470862)]
#
# --------------
#
# Document  261
#
# Document topics: [(0, 0.29694134), (2, 0.40069395), (4, 0.030608073), (6, 0.09563222), (9, 0.17474669)]
#
# --------------
#
# Document  262
#
# Document topics: [(7, 0.9608661)]
#
# --------------
#
# Document  263
#
# Document topics: [(0, 0.66094375), (4, 0.023604168), (6, 0.10669542), (7, 0.058228888), (9, 0.14730974)]
#
# --------------
#
# Document  264
#
# Document topics: [(0, 0.23720844), (2, 0.48383588), (6, 0.1924348), (9, 0.08309146)]
#
# --------------
#
# Document  265
#
# Document topics: [(7, 0.23348731), (9, 0.7614805)]
#
# --------------
#
# Document  266
#
# Document topics: [(7, 0.79483795), (9, 0.2029936)]
#
# --------------
#
# Document  267
#
# Document topics: [(0, 0.13542634), (7, 0.86197567)]
#
# --------------
#
# Document  268
#
# Document topics: [(0, 0.18086243), (1, 0.01605398), (3, 0.05125121), (6, 0.1224901), (9, 0.6286036)]
#
# --------------
#
# Document  269
#
# Document topics: [(0, 0.2296079), (1, 0.11154202), (4, 0.3305149), (6, 0.22663642), (9, 0.10045785)]
#
# --------------
#
# Document  270
#
# Document topics: [(0, 0.028132567), (4, 0.31711474), (5, 0.15629685), (6, 0.11021112), (7, 0.34874815), (9, 0.031322382)]
#
# --------------
#
# Document  271
#
# Document topics: [(0, 0.09958269), (5, 0.88685495)]
#
# --------------
#
# Document  272
#
# Document topics: [(0, 0.742119), (4, 0.019075617), (7, 0.013799079), (9, 0.22382261)]
#
# --------------
#
# Document  273
#
# Document topics: [(0, 0.9437419)]
#
# --------------
#
# Document  274
#
# Document topics: [(0, 0.9950543)]
#
# --------------
#
# Document  275
#
# Document topics: [(0, 0.022943407), (4, 0.26081935), (6, 0.015025969), (7, 0.6996764)]
#
# --------------
#
# Document  276
#
# Document topics: [(1, 0.47256738), (4, 0.070144184), (5, 0.18447646), (7, 0.26940212)]
#
# --------------
#
# Document  277
#
# Document topics: [(0, 0.0841381), (6, 0.20257127), (7, 0.034345243), (8, 0.47394934), (9, 0.20439278)]
#
# --------------
#
# Document  278
#
# Document topics: [(7, 0.99695885)]
#
# --------------
#
# Document  279
#
# Document topics: [(6, 0.15052576), (7, 0.8466666)]
#
# --------------
#
# Document  280
#
# Document topics: [(0, 0.23102123), (4, 0.56229556), (6, 0.106060125), (9, 0.099570274)]
#
# --------------
#
# Document  281
#
# Document topics: [(6, 0.09352453), (9, 0.90298134)]
#
# --------------
#
# Document  282
#
# Document topics: [(4, 0.31758687), (7, 0.6759605)]
#
# --------------
#
# Document  283
#
# Document topics: [(0, 0.08685451), (1, 0.38220638), (6, 0.065689124), (7, 0.41242877), (9, 0.052236903)]
#
# --------------
#
# Document  284
#
# Document topics: [(0, 0.2280389), (4, 0.6672144), (9, 0.10235704)]
#
# --------------
#
# Document  285
#
# Document topics: [(3, 0.027673014), (6, 0.17642243), (7, 0.6044336), (9, 0.19043988)]
#
# --------------
#
# Document  286
#
# Document topics: [(0, 0.038008988), (4, 0.100083135), (6, 0.06678303), (9, 0.7940011)]
#
# --------------
#
# Document  287
#
# Document topics: [(0, 0.22161199), (2, 0.55748165), (6, 0.101620734), (7, 0.038223017), (9, 0.07929533)]
#
# --------------
#
# Document  288
#
# Document topics: [(0, 0.70832074), (3, 0.05241459), (4, 0.010525772), (6, 0.1523472), (7, 0.03159895), (9, 0.038060445)]
#
# --------------
#
# Document  289
#
# Document topics: [(3, 0.2169134), (7, 0.2953035), (9, 0.4846851)]
#
# --------------
#
# Document  290
#
# Document topics: [(0, 0.52631974), (6, 0.14548136), (7, 0.25891805), (9, 0.06750541)]
#
# --------------
#
# Document  291
#
# Document topics: [(0, 0.15206707), (7, 0.64136946), (9, 0.20258537)]
#
# --------------
#
# Document  292
#
# Document topics: [(6, 0.98269)]
#
# --------------
#
# Document  293
#
# Document topics: [(6, 0.32050496), (7, 0.4454426), (9, 0.23113523)]
#
# --------------
#
# Document  294
#
# Document topics: [(0, 0.08932399), (1, 0.21337156), (2, 0.075169116), (4, 0.08869917), (5, 0.04879213), (6, 0.11779068), (7, 0.2988233), (9, 0.067560405)]
#
# --------------
#
# Document  295
#
# Document topics: [(0, 0.12611566), (6, 0.06410007), (9, 0.80709124)]
#
# --------------
#
# Document  296
#
# Document topics: [(6, 0.5787258), (7, 0.1651157), (9, 0.25418627)]
#
# --------------
#
# Document  297
#
# Document topics: [(0, 0.2118397), (4, 0.5292968), (6, 0.18822148), (9, 0.069666125)]
#
# --------------
#
# Document  298
#
# Document topics: [(0, 0.3344933), (4, 0.16503894), (5, 0.4936703)]
#
# --------------
#
# Document  299
#
# Document topics: [(0, 0.16129121), (5, 0.65328914), (6, 0.05665917), (9, 0.12660947)]
#
# --------------
#
# Document  300
#
# Document topics: [(7, 0.43971935), (9, 0.5575499)]
#
# --------------
#
# Document  301
#
# Document topics: [(0, 0.9939987)]
#
# --------------
#
# Document  302
#
# Document topics: [(0, 0.024166683), (6, 0.13006537), (7, 0.6675497), (9, 0.17707509)]
#
# --------------
#
# Document  303
#
# Document topics: [(7, 0.7584817), (8, 0.23599972)]
#
# --------------
#
# Document  304
#
# Document topics: [(0, 0.68275046), (5, 0.020123903), (6, 0.07025065), (7, 0.18884301), (9, 0.037245635)]
#
# --------------
#
# Document  305
#
# Document topics: [(4, 0.9372424), (9, 0.055799574)]
#
# --------------
#
# Document  306
#
# Document topics: [(0, 0.048063114), (4, 0.7042529), (6, 0.120047875), (9, 0.12643816)]
#
# --------------
#
# Document  307
#
# Document topics: [(0, 0.20719029), (6, 0.02990019), (9, 0.76085633)]
#
# --------------
#
# Document  308
#
# Document topics: [(2, 0.39121854), (7, 0.18479656), (9, 0.42009506)]
#
# --------------
#
# Document  309
#
# Document topics: [(0, 0.044117894), (1, 0.066874936), (3, 0.057625193), (6, 0.075275876), (7, 0.06244961), (9, 0.6931779)]
#
# --------------
#
# Document  310
#
# Document topics: [(0, 0.14429562), (1, 0.20322306), (6, 0.06667584), (7, 0.4803138), (9, 0.102201626)]
#
# --------------
#
# Document  311
#
# Document topics: [(0, 0.12511173), (2, 0.060730238), (3, 0.046248935), (5, 0.37038195), (6, 0.18233061), (7, 0.09570039), (8, 0.019369412), (9, 0.09997393)]
#
# --------------
#
# Document  312
#
# Document topics: [(7, 0.059319258), (9, 0.936029)]
#
# --------------
#
# Document  313
#
# Document topics: [(6, 0.108755805), (7, 0.8171734), (9, 0.07161413)]
#
# --------------
#
# Document  314
#
# Document topics: [(0, 0.48129657), (7, 0.23467651), (8, 0.28057778)]
#
# --------------
#
# Document  315
#
# Document topics: [(0, 0.82969815), (6, 0.13455676), (7, 0.01448279), (9, 0.020049889)]
#
# --------------
#
# Document  316
#
# Document topics: [(0, 0.022679323), (3, 0.40811104), (4, 0.050861873), (6, 0.072808996), (9, 0.44442245)]
#
# --------------
#
# Document  317
#
# Document topics: [(0, 0.08780234), (6, 0.90938)]
#
# --------------
#
# Document  318
#
# Document topics: [(4, 0.022766149), (7, 0.7233769), (9, 0.25161284)]
#
# --------------
#
# Document  319
#
# Document topics: [(0, 0.08652784), (5, 0.39722505), (6, 0.28776747), (9, 0.22559437)]
#
# --------------
#
# Document  320
#
# Document topics: [(3, 0.35784438), (4, 0.42077628), (9, 0.21408604)]
#
# --------------
#
# Document  321
#
# Document topics: [(3, 0.7119451), (4, 0.06283576), (6, 0.15015191), (7, 0.028470509), (9, 0.044854153)]
#
# --------------
#
# Document  322
#
# Document topics: [(0, 0.089181036), (1, 0.6089773), (3, 0.04947527), (7, 0.21938877), (9, 0.0317783)]
#
# --------------
#
# Document  323
#
# Document topics: [(3, 0.53665966), (6, 0.19069771), (9, 0.27113044)]
#
# --------------
#
# Document  324
#
# Document topics: [(3, 0.08983413), (4, 0.58795863), (7, 0.21621369), (9, 0.10320243)]
#
# --------------
#
# Document  325
#
# Document topics: [(7, 0.9357094)]
#
# --------------
#
# Document  326
#
# Document topics: [(6, 0.64702934), (8, 0.34839827)]
#
# --------------
#
# Document  327
#
# Document topics: [(0, 0.7874908), (7, 0.18393315)]
#
# --------------
#
# Document  328
#
# Document topics: [(7, 0.9961531)]
#
# --------------
#
# Document  329
#
# Document topics: [(0, 0.04563235), (4, 0.7335415), (6, 0.21768646)]
#
# --------------
#
# Document  330
#
# Document topics: [(0, 0.33860004), (1, 0.5997569), (9, 0.05840153)]
#
# --------------
#
# Document  331
#
# Document topics: [(0, 0.083405115), (4, 0.74657613), (6, 0.09220979), (9, 0.076504245)]
#
# --------------
#
# Document  332
#
# Document topics: [(4, 0.013145709), (6, 0.58345324), (7, 0.40242726)]
#
# --------------
# Document  333
#
# Document topics: [(3, 0.45922306), (6, 0.12659457), (7, 0.019946702), (9, 0.3929138)]
#
# --------------
#
# Document  334
#
# Document topics: [(7, 0.77043825), (9, 0.22619979)]
#
# --------------
#
# Document  335
#
# Document topics: [(0, 0.571786), (5, 0.3424748), (7, 0.080353364)]
#
# --------------
#
# Document  336
#
# Document topics: [(0, 0.8174886), (4, 0.029998038), (7, 0.15014805)]
#
# --------------
#
# Document  337
#
# Document topics: [(0, 0.28781208), (1, 0.03991108), (4, 0.02550022), (6, 0.24939327), (7, 0.017695604), (8, 0.2665455), (9, 0.112850584)]
#
# --------------
#
# Document  338
#
# Document topics: [(0, 0.8879518), (4, 0.017028783), (6, 0.093812294)]
#
# --------------
#
# Document  339
#
# Document topics: [(0, 0.2883728), (1, 0.47183317), (6, 0.20680194), (7, 0.03131572)]
#
# --------------
#
# Document  340
#
# Document topics: [(4, 0.1206586), (7, 0.8765726)]
#
# --------------
#
# Document  341
#
# Document topics: [(0, 0.6922494), (6, 0.12734602), (9, 0.17644648)]
#
# --------------
#
# Document  342
#
# Document topics: [(0, 0.07865217), (1, 0.26785788), (6, 0.06777246), (7, 0.54751444), (9, 0.0375968)]
#
# --------------
#
# Document  343
#
# Document topics: [(3, 0.040349863), (6, 0.09856665), (9, 0.85923123)]
#
# --------------
#
# Document  344
#
# Document topics: [(0, 0.24795958), (2, 0.45255658), (6, 0.058579106), (9, 0.23739521)]
#
# --------------
#
# Document  345
#
# Document topics: [(4, 0.022229234), (6, 0.81130815), (9, 0.16411318)]
#
# --------------
#
# Document  346
#
# Document topics: [(0, 0.08861939), (1, 0.2750775), (3, 0.27500904), (6, 0.105517566), (7, 0.25191644)]
#
# --------------
#
# Document  347
#
# Document topics: [(0, 0.05768747), (1, 0.016135342), (3, 0.016704826), (4, 0.042086244), (6, 0.7798667), (7, 0.03408944), (8, 0.0102095045), (9, 0.043064035)]
#
# --------------
#
# Document  348
#
# Document topics: [(0, 0.31575066), (1, 0.5665169), (6, 0.04735276), (9, 0.069379516)]
#
# --------------
#
# Document  349
#
# Document topics: [(3, 0.67556846), (6, 0.15516526), (7, 0.06255634), (9, 0.10369427)]
#
# --------------
#
# Document  350
#
# Document topics: [(0, 0.8004079), (5, 0.03600556), (6, 0.10247737), (9, 0.05949145)]
#
# --------------
#
# Document  351
#
# Document topics: [(0, 0.162513), (5, 0.33853248), (6, 0.23098367), (9, 0.26649988)]
#
# --------------
#
# Document  352
#
# Document topics: [(0, 0.1430068), (4, 0.17030269), (8, 0.33780468), (9, 0.34565938)]
#
# --------------
#
# Document  353
#
# Document topics: [(0, 0.22074607), (6, 0.11856039), (9, 0.6584638)]
#
# --------------
#
# Document  354
#
# Document topics: [(0, 0.96896094)]
#
# --------------
#
# Document  355
#
# Document topics: [(3, 0.99062276)]
#
# --------------
#
# Document  356
#
# Document topics: [(0, 0.058124118), (4, 0.57019913), (6, 0.24262333), (9, 0.12773158)]
#
# --------------
#
# Document  357
#
# Document topics: [(0, 0.77852327), (5, 0.01992827), (6, 0.06678482), (7, 0.10682947), (9, 0.026988802)]
#
# --------------
#
# Document  358
#
# Document topics: [(6, 0.07112725), (9, 0.92610395)]
#
# --------------
#
# Document  359
#
# Document topics: [(7, 0.9950267)]
#
# --------------
#
# Document  360
#
# Document topics: [(6, 0.9819987)]
#
# --------------
#
# Document  361
#
# Document topics: [(9, 0.9932314)]
#
# --------------
#
# Document  362
#
# Document topics: [(7, 0.98548156)]
#
# --------------
#
# Document  363
#
# Document topics: [(0, 0.4080742), (3, 0.028449355), (4, 0.04317907), (6, 0.15281965), (7, 0.2906875), (9, 0.07606152)]
#
# --------------
#
# Document  364
#
# Document topics: [(4, 0.1790743), (6, 0.08587834), (7, 0.7321778)]
#
# --------------
#
# Document  365
#
# Document topics: [(6, 0.8759162), (7, 0.117125705)]
#
# --------------
#
# Document  366
#
# Document topics: [(1, 0.07282481), (6, 0.15449259), (9, 0.76912844)]
#
# --------------
#
# Document  367
#
# Document topics: [(0, 0.08144528), (1, 0.40406737), (4, 0.01979334), (6, 0.12546383), (7, 0.021593062), (9, 0.34658977)]
#
# --------------
#
# Document  368
#
# Document topics: [(0, 0.23488134), (1, 0.46333864), (4, 0.23999088), (6, 0.05880337)]
#
# --------------
#
# Document  369
#
# Document topics: [(4, 0.26265284), (6, 0.7342931)]
#
# --------------
#
# Document  370
#
# Document topics: [(0, 0.9100818), (6, 0.03805568), (9, 0.050391536)]
#
# --------------
#
# Document  371
#
# Document topics: [(0, 0.15519692), (9, 0.84310776)]
#
# --------------
#
# Document  372
#
# Document topics: [(0, 0.3290859), (3, 0.10013149), (6, 0.44678316), (7, 0.01751141), (8, 0.020014362), (9, 0.08622498)]
#
# --------------
#
# Document  373
#
# Document topics: [(0, 0.25172472), (6, 0.015931863), (7, 0.04474632), (9, 0.68639207)]
#
# --------------
#
# Document  374
#
# Document topics: [(4, 0.9943026)]
#
# --------------
#
# Document  375
#
# Document topics: [(0, 0.07669659), (6, 0.13340443), (8, 0.017745262), (9, 0.76966345)]
#
# --------------
#
# Document  376
#
# Document topics: [(0, 0.98593473)]
#
# --------------
#
# Document  377
#
# Document topics: [(0, 0.1781855), (1, 0.6735808), (6, 0.11130619), (9, 0.03562567)]
#
# --------------
#
# Document  378
#
# Document topics: [(0, 0.08773286), (3, 0.052133817), (6, 0.18143283), (9, 0.67316175)]
#
# --------------
#
# Document  379
#
# Document topics: [(0, 0.27516347), (6, 0.042084124), (9, 0.6817302)]
#
# --------------
#
# Document  380
#
# Document topics: [(0, 0.32927632), (4, 0.37083796), (6, 0.18766263), (9, 0.110814355)]
#
# --------------
#
# Document  381
#
# Document topics: [(8, 0.9470515)]
#
# --------------
#
# Document  382
#
# Document topics: [(6, 0.35254237), (7, 0.41442576), (9, 0.23042911)]
#
# --------------
#
# Document  383
#
# Document topics: [(0, 0.029294973), (4, 0.25316504), (6, 0.6706847), (9, 0.045645367)]
#
# --------------
#
# Document  384
#
# Document topics: [(0, 0.10941116), (2, 0.19318062), (4, 0.05335507), (6, 0.25786096), (7, 0.1857835), (9, 0.20002213)]
#
# --------------
#
# Document  385
#
# Document topics: [(0, 0.18162264), (1, 0.3533851), (4, 0.026106628), (6, 0.2730154), (7, 0.034702852), (9, 0.13029386)]
#
# --------------
#
# Document  386
#
# Document topics: [(0, 0.2719083), (3, 0.4471432), (8, 0.25269994), (9, 0.0239309)]
#
# --------------
#
# Document  387
#
# Document topics: [(0, 0.38118035), (1, 0.1944135), (4, 0.06613219), (7, 0.20750679), (9, 0.14885832)]
#
# --------------
#
# Document  388
#
# Document topics: [(5, 0.07156317), (9, 0.9225532)]
#
# --------------
#
# Document  389
#
# Document topics: [(0, 0.31006384), (5, 0.30409843), (6, 0.15106872), (9, 0.23207794)]
#
# --------------
#
# Document  390
#
# Document topics: [(0, 0.65136397), (6, 0.34667972)]
#
# --------------
#
# Document  391
#
# Document topics: [(0, 0.10185515), (1, 0.13199516), (3, 0.43824726), (4, 0.083198085), (6, 0.17879644), (7, 0.029008642), (9, 0.03644729)]
#
# --------------
#
# Document  392
#
# Document topics: [(0, 0.9952119)]
#
# --------------
#
# Document  393
#
# Document topics: [(3, 0.267777), (6, 0.5492936), (9, 0.17942862)]
#
# --------------
#
# Document  394
#
# Document topics: [(5, 0.79987705), (7, 0.17154542)]
#
# --------------
#
# Document  395
#
# Document topics: [(0, 0.71168864), (6, 0.05379841), (7, 0.13056411), (9, 0.1029553)]
#
# --------------
#
# Document  396
#
# Document topics: [(0, 0.85900635), (6, 0.049434435), (9, 0.09063061)]
#
# --------------
#
# Document  397
#
# Document topics: [(5, 0.7716002), (7, 0.19982366)]
#
# --------------
#
# Document  398
#
# Document topics: [(0, 0.07471933), (3, 0.74582785), (6, 0.0877088), (9, 0.09052168)]
#
# --------------
#
# Document  399
#
# Document topics: [(7, 0.13219918), (9, 0.85946596)]
#
# --------------
#
# Document  400
#
# Document topics: [(6, 0.98333097)]
#
# --------------
#
# Document  401
#
# Document topics: [(0, 0.4202644), (8, 0.5597309)]
#
# --------------
#
# Document  402
#
# Document topics: [(0, 0.62729776), (4, 0.3104289), (7, 0.060386248)]
#
# --------------
#
# Document  403
#
# Document topics: [(0, 0.7831519), (1, 0.098750874), (4, 0.085825264), (6, 0.03011324)]
#
# --------------
#
# Document  404
#
# Document topics: [(0, 0.059065264), (1, 0.48415992), (3, 0.1730182), (6, 0.034333076), (7, 0.06609069), (9, 0.18259332)]
#
# --------------
#
# Document  405
#
# Document topics: [(3, 0.39851725), (6, 0.5130197), (9, 0.08549642)]
#
# --------------
#
# Document  406
#
# Document topics: [(0, 0.07988292), (1, 0.33418122), (3, 0.045997005), (4, 0.045476943), (6, 0.045729935), (7, 0.11202039), (8, 0.3097445), (9, 0.026590325)]
#
# --------------
#
# Document  407
#
# Document topics: [(0, 0.24896438), (5, 0.45263937), (6, 0.12422272), (9, 0.17274122)]
#
# --------------
#
# Document  408
#
# Document topics: [(5, 0.9357003)]
#
# --------------
#
# Document  409
#
# Document topics: [(6, 0.54956114), (7, 0.34329176), (9, 0.106234185)]
#
# --------------
#
# Document  410
#
# Document topics: [(0, 0.6634117), (7, 0.24157552), (9, 0.09256485)]
#
# --------------
#
# Document  411
#
# Document topics: [(7, 0.2876625), (9, 0.7098213)]
#
# --------------
#
# Document  412
#
# Document topics: [(0, 0.39795604), (4, 0.15086342), (6, 0.12068761), (7, 0.17432085), (8, 0.11829417), (9, 0.037077688)]
#
# --------------
# Document  413
#
# Document topics: [(0, 0.17191614), (1, 0.059581712), (2, 0.17428957), (5, 0.05384394), (6, 0.17102616), (7, 0.23290372), (9, 0.13592586)]
#
# --------------
#
# Document  414
#
# Document topics: [(0, 0.90162474), (6, 0.0719013), (9, 0.024025906)]
#
# --------------
#
# Document  415
#
# Document topics: [(0, 0.08606561), (1, 0.6712429), (4, 0.055675283), (6, 0.04080268), (7, 0.13808893)]
#
# --------------
#
# Document  416
#
# Document topics: [(7, 0.9689612)]
#
# --------------
#
# Document  417
#
# Document topics: [(3, 0.13141857), (9, 0.8665958)]
#
# --------------
#
# Document  418
#
# Document topics: [(0, 0.19640243), (5, 0.437793), (6, 0.15401623), (9, 0.20923454)]
#
# --------------
#
# Document  419
#
# Document topics: [(0, 0.9501265), (4, 0.046974275)]
#
# --------------
#
# Document  420
#
# Document topics: [(7, 0.5795903), (9, 0.41481468)]
#
# --------------
#
# Document  421
#
# Document topics: [(9, 0.99473584)]
#
# --------------
#
# Document  422
#
# Document topics: [(6, 0.077684514), (7, 0.07080997), (9, 0.84812325)]
#
# --------------
#
# Document  423
#
# Document topics: [(0, 0.03038795), (6, 0.8929822), (8, 0.05226915), (9, 0.02206153)]
#
# --------------
#
# Document  424
#
# Document topics: [(3, 0.21404439), (4, 0.20739058), (5, 0.011639227), (7, 0.53344685), (9, 0.031584498)]
#
# --------------
#
# Document  425
#
# Document topics: [(6, 0.92659223), (7, 0.06956073)]
#
# --------------
#
# Document  426
#
# Document topics: [(0, 0.06903424), (1, 0.32160395), (3, 0.13081762), (6, 0.049147263), (7, 0.15891482), (8, 0.012057823), (9, 0.25801483)]
#
# --------------
#
# Document  427
#
# Document topics: [(0, 0.04556231), (9, 0.9526867)]
#
# --------------
#
# Document  428
#
# Document topics: [(0, 0.39927796), (7, 0.084973), (8, 0.121930145), (9, 0.39136937)]
#
# --------------
#
# Document  429
#
# Document topics: [(0, 0.4419046), (2, 0.30887508), (4, 0.047128573), (6, 0.10147753), (9, 0.09947236)]
#
# --------------
#
# Document  430
#
# Document topics: [(0, 0.2087902), (4, 0.052117206), (5, 0.29665208), (6, 0.11588979), (7, 0.15869048), (9, 0.16672362)]
#
# --------------
#
# Document  431
#
# Document topics: [(0, 0.66398746), (3, 0.060281195), (6, 0.22043125), (7, 0.018568935), (9, 0.03620083)]
#
# --------------
#
# Document  432
#
# Document topics: [(0, 0.08055959), (3, 0.4139067), (7, 0.032636195), (9, 0.47153974)]
#
# --------------
#
# Document  433
#
# Document topics: [(0, 0.23231736), (6, 0.2880907), (7, 0.071030185), (8, 0.40664437)]
#
# --------------
#
# Document  434
#
# Document topics: [(0, 0.35655534), (3, 0.62711483)]
#
# --------------
#
# Document  435
#
# Document topics: [(7, 0.9962017)]
#
# --------------
#
# Document  436
#
# Document topics: [(0, 0.9798692), (4, 0.018340597)]
#
# --------------
#
# Document  437
#
# Document topics: [(0, 0.08021558), (1, 0.258227), (4, 0.5920384), (6, 0.035063274), (7, 0.03357064)]
#
# --------------
#
# Document  438
#
# Document topics: [(7, 0.77158594), (9, 0.2258576)]
#
# --------------
#
# Document  439
#
# Document topics: [(2, 0.3034853), (6, 0.12698369), (7, 0.15188403), (9, 0.4145536)]
#
# --------------
#
# Document  440
#
# Document topics: [(0, 0.16572095), (4, 0.12681702), (6, 0.6387483), (7, 0.067305066)]
#
# --------------
#
# Document  441
#
# Document topics: [(0, 0.031002153), (6, 0.05791038), (7, 0.90830916)]
#
# --------------
#
# ...
#
# Document topics: [(0, 0.21293698), (2, 0.32034957), (4, 0.21477333), (6, 0.20268515), (9, 0.048223782)]
#
# --------------
#
# Document  479
#
# Document topics: [(0, 0.060097184), (6, 0.6066932), (9, 0.33206373)]
#
# --------------
#
# Document  480
#
# Document topics: [(0, 0.079718985), (4, 0.07356268), (7, 0.46383667), (9, 0.38169795)]
#
# --------------
#
# Document  481
#
# Document topics: [(0, 0.21753344), (4, 0.6866215), (6, 0.09314186)]
#
# --------------
#
# Document  482
#
# Document topics: [(0, 0.035066962), (3, 0.21939726), (4, 0.19930917), (6, 0.11435606), (7, 0.43076167)]
#
# --------------
#
# Document  483
#
# Document topics: [(1, 0.62878156), (3, 0.20322457), (6, 0.1563248)]
#
# --------------
#
# Document  484
#
# Document topics: [(0, 0.08220943), (1, 0.3083177), (6, 0.2837457), (9, 0.32330748)]
#
# --------------
#
# Document  485
#
# Document topics: [(0, 0.117198646), (6, 0.88030857)]
#
# --------------
#
# Document  486
#
# Document topics: [(0, 0.2185057), (2, 0.26342854), (3, 0.0119247055), (4, 0.048130058), (6, 0.16603673), (7, 0.11436529), (9, 0.17727411)]
#
# --------------
#
# Document  487
#
# Document topics: [(3, 0.47399074), (7, 0.50100535)]
#
# --------------
#
# Document  488
#
# Document topics: [(0, 0.84585357), (6, 0.071791835), (9, 0.08078124)]
#
# --------------
#
# Document  489
#
# Document topics: [(6, 0.07724996), (7, 0.91849405)]
#
# --------------
#
# Document  490
#
# Document topics: [(0, 0.06601747), (3, 0.75695807), (6, 0.08005026), (9, 0.09470952)]
#
# --------------
#
# Document  491
#
# Document topics: [(0, 0.24155796), (6, 0.4180287), (7, 0.338239)]
#
# --------------
#
# Document  492
#
# Document topics: [(9, 0.9833297)]
#
# --------------
#
# Document  493
#
# Document topics: [(0, 0.13550834), (6, 0.19183356), (9, 0.67150646)]
#
# --------------
# Document  494
#
# Document topics: [(0, 0.1678572), (1, 0.06840878), (3, 0.36867225), (4, 0.030937474), (6, 0.11838127), (7, 0.22488084), (9, 0.020344011)]
#
# --------------
#
# Document  495
#
# Document topics: [(6, 0.8200949), (7, 0.17676722)]
#
# --------------
#
# Document  496
#
# Document topics: [(0, 0.06022886), (3, 0.013445015), (4, 0.6634101), (6, 0.12575927), (7, 0.08101539), (9, 0.05533468)]
#
# --------------
#
# Document  497
#
# Document topics: [(0, 0.7394961), (4, 0.015493429), (7, 0.059359025), (9, 0.18326052)]
#
# --------------
#
# Document  498
#
# Document topics: [(6, 0.98043036)]
#
# --------------
#
# Document  499
#
# Document topics: [(0, 0.04702534), (6, 0.2606285), (8, 0.5406398), (9, 0.15004848)]
#
# --------------
#
# Document  500
#
# Document topics: [(0, 0.36334974), (4, 0.06360374), (5, 0.30865654), (6, 0.17032608), (7, 0.09313261)]
#
# --------------
#
# Document  501
#
# Document topics: [(6, 0.114264876), (7, 0.8827933)]
#
# --------------
#
# Document  502
#
# Document topics: [(0, 0.17924334), (4, 0.069355175), (5, 0.38985103), (6, 0.25826472), (7, 0.038322177), (9, 0.06410318)]
#
# --------------
#
# Document  503
#
# Document topics: [(6, 0.9955438)]
#
# --------------
#
# Document  504
#
# Document topics: [(9, 0.9943018)]
#
# --------------
#
# Document  505
#
# Document topics: [(0, 0.34152773), (4, 0.15025635), (9, 0.50658387)]
#
# --------------
#
# Document  506
#
# Document topics: [(0, 0.22242187), (4, 0.08221715), (6, 0.077040404), (7, 0.21421573), (8, 0.27554637), (9, 0.12752736)]
#
# --------------
#
# Document  507
#
# Document topics: [(0, 0.041019455), (4, 0.750131), (6, 0.14392093), (9, 0.063526325)]
#
# --------------
#
# Document  508
#
# Document topics: [(0, 0.19514942), (4, 0.06511343), (6, 0.11788333), (9, 0.6198263)]
#
# --------------
#
# Document  509
#
# Document topics: [(2, 0.30031615), (4, 0.06195548), (7, 0.14301169), (9, 0.49224696)]
#
# --------------
#
# Document  510
#
# Document topics: [(7, 0.17251131), (9, 0.82448065)]
#
# --------------
#
# Document  511
#
# Document topics: [(0, 0.2081356), (4, 0.055891037), (6, 0.16649291), (7, 0.14267613), (8, 0.27156883), (9, 0.15445413)]
#
# --------------
#
# Document  512
#
# Document topics: [(4, 0.749695), (8, 0.21393529)]
#
# --------------
#
# Document  513
#
# Document topics: [(0, 0.098012775), (5, 0.48647192), (6, 0.16467871), (9, 0.24666911)]
#
# --------------
#
# Document  514
#
# Document topics: [(6, 0.9958709)]
#
# --------------
#
# Document  515
#
# Document topics: [(0, 0.33271953), (1, 0.38691372), (4, 0.020194128), (6, 0.08630617), (9, 0.17263466)]
#
# --------------
#
# Document  516
#
# Document topics: [(0, 0.9909987)]
#
# --------------
#
# Document  517
#
# Document topics: [(6, 0.4638534), (7, 0.36779577), (9, 0.16638428)]
#
# --------------
#
# Document  518
#
# Document topics: [(6, 0.99558735)]
#
# --------------
#
# Document  519
#
# Document topics: [(0, 0.7166639), (6, 0.08396321), (7, 0.16942023), (9, 0.028440997)]
#
# --------------
#
# Document  520
#
# Document topics: [(3, 0.42645037), (7, 0.5030819), (9, 0.067396775)]
#
# --------------
#
# Document  521
#
# Document topics: [(6, 0.4240412), (7, 0.5721847)]
#
# --------------
#
# Document  522
#
# Document topics: [(4, 0.9124509), (7, 0.08360727)]
#
# --------------
#
# Document  523
#
# Document topics: [(0, 0.08298642), (9, 0.9138129)]
#
# --------------
#
# Document  524
#
# Document topics: [(0, 0.21730842), (4, 0.030274514), (5, 0.45590723), (6, 0.13968503), (8, 0.041265287), (9, 0.11496061)]
#
# --------------
#
# Document  525
#
# Document topics: [(0, 0.1900686), (5, 0.5177506), (9, 0.2890962)]
#
# --------------
#
# Document  526
#
# Document topics: [(0, 0.09472177), (1, 0.017125197), (4, 0.04387709), (6, 0.8427251)]
#
# --------------
#
# Document  527
#
# Document topics: [(8, 0.95713615)]
#
# --------------
#
# Document  528
#
# Document topics: [(3, 0.11672181), (7, 0.8789293)]
#
# --------------
#
# Document  529
#
# Document topics: [(0, 0.3039228), (3, 0.103445694), (4, 0.034946747), (6, 0.19776243), (7, 0.015245413), (9, 0.3437614)]
#
# --------------
#
# Document  530
#
# Document topics: [(0, 0.7305346), (6, 0.10058011), (7, 0.08815365), (9, 0.07961813)]
#
# --------------
#
# Document  531
#
# Document topics: [(0, 0.20603096), (3, 0.37843075), (7, 0.28429177), (9, 0.12524539)]
#
# --------------
#
# Document  532
#
# Document topics: [(0, 0.19272669), (6, 0.10494624), (7, 0.19249986), (8, 0.50757957)]
#
# --------------
#
# Document  533
#
# Document topics: [(0, 0.44823554), (2, 0.043862056), (3, 0.2958482), (4, 0.037451677), (5, 0.01694594), (6, 0.13888475), (7, 0.018140106)]
#
# --------------
#
# Document  534
#
# Document topics: [(0, 0.70253325), (7, 0.29233742)]
#
# --------------
#
# Document  535
#
# Document topics: [(4, 0.03543616), (9, 0.9614863)]
#
# --------------
#
# Document  536
#
# Document topics: [(6, 0.9061324), (7, 0.09050555)]
#
# --------------
#
# Document  537
#
# Document topics: [(4, 0.12483472), (7, 0.87228703)]
#
# --------------
#
# Document  538
#
# Document topics: [(3, 0.4445568), (6, 0.11367307), (7, 0.037601218), (9, 0.40275016)]
#
# --------------
#
# Document  539
#
# Document topics: [(0, 0.92452705), (9, 0.07323782)]
#
# --------------
#
# Document  540
#
# Document topics: [(0, 0.049136497), (6, 0.6949775), (7, 0.11131218), (9, 0.14278777)]
#
# --------------
#
# Document  541
#
# Document topics: [(0, 0.32473215), (7, 0.6305167), (9, 0.042951312)]
#
# --------------
#
# Document  542
#
# Document topics: [(0, 0.57930183), (4, 0.32567596), (7, 0.05829281), (9, 0.035009924)]
#
# --------------
#
# Document  543
#
# Document topics: [(0, 0.18008456), (5, 0.05478627), (6, 0.66424924), (9, 0.098918766)]
#
# --------------
#
# Document  544
#
# Document topics: [(0, 0.892045), (7, 0.10517662)]
#
# --------------
#
# Document  545
#
# Document topics: [(0, 0.5186964), (4, 0.32748505), (5, 0.019056648), (9, 0.13358282)]
#
# --------------
#
# Document  546
#
# Document topics: [(0, 0.88310057), (7, 0.11316031)]
#
# --------------
#
# Document  547
#
# Document topics: [(0, 0.08310112), (5, 0.5384262), (6, 0.19990307), (9, 0.1774264)]
#
# --------------
#
# Document  548
#
# Document topics: [(0, 0.1473847), (8, 0.6360001), (9, 0.20661317)]
#
# --------------
#
# Document  549
#
# Document topics: [(4, 0.07682802), (7, 0.14582446), (9, 0.7760792)]
#
# --------------
#
# Document  550
#
# Document topics: [(0, 0.053434107), (1, 0.08504234), (4, 0.016224675), (5, 0.2010708), (6, 0.1997783), (7, 0.3324075), (9, 0.10452404)]
#
# --------------
#
# Document  551
#
# Document topics: [(0, 0.9066743), (6, 0.06366332), (9, 0.027800228)]
#
# --------------
#
# Document  552
#
# Document topics: [(0, 0.18460602), (5, 0.8000059)]
#
# --------------
#
# Document  553
#
# Document topics: [(0, 0.043706145), (4, 0.7646397), (7, 0.18883102)]
#
# --------------
#
# Document  554
#
# Document topics: [(0, 0.04627593), (3, 0.6095923), (6, 0.13741374), (7, 0.041482583), (9, 0.16407771)]
#
# --------------
#
# Document  555
#
# Document topics: [(0, 0.2422918), (5, 0.09936454), (6, 0.12690091), (8, 0.44033355), (9, 0.08876123)]
#
# --------------
#
# Document  556
#
# Document topics: [(4, 0.7620529), (7, 0.15432036), (9, 0.08075737)]
#
# --------------
#
# Document  557
#
# Document topics: [(0, 0.32456866), (6, 0.02525927), (8, 0.55183065), (9, 0.09574343)]
#
# --------------
#
# Document  558
#
# Document topics: [(0, 0.078884356), (4, 0.59975225), (7, 0.19228777), (9, 0.12781212)]
#
# --------------
#
# Document  559
#
# Document topics: [(5, 0.21631578), (6, 0.18004878), (7, 0.32482892), (9, 0.2762955)]
#
# --------------
#
# Document  560
#
# Document topics: [(0, 0.728573), (6, 0.057144973), (7, 0.018130615), (8, 0.111597046), (9, 0.08368758)]
#
# --------------
#
# Document  561
#
# Document topics: [(0, 0.0736966), (1, 0.5452189), (3, 0.24346052), (6, 0.13617784)]
#
# --------------
#
# Document  562
#
# Document topics: [(0, 0.69136095), (6, 0.03813586), (9, 0.26875284)]
#
# --------------
#
# Document  563
#
# Document topics: [(0, 0.16660032), (1, 0.048118968), (4, 0.039617438), (5, 0.37485564), (6, 0.22533362), (9, 0.14469562)]
#
# --------------
#
# Document  564
#
# Document topics: [(0, 0.15510407), (6, 0.116422534), (8, 0.6322205), (9, 0.09254851)]
#
# --------------
#
# Document  565
#
# Document topics: [(4, 0.87680686), (6, 0.030280435), (7, 0.038372755), (9, 0.051640816)]
#
# --------------
#
# Document  566
#
# Document topics: [(0, 0.1443412), (1, 0.34408563), (7, 0.42500305), (9, 0.08483559)]
#
# --------------
#
# Document  567
#
# Document topics: [(0, 0.22202463), (1, 0.50113136), (6, 0.1756761), (9, 0.099846)]
#
# --------------
#
# Document  568
#
# Document topics: [(0, 0.7407614), (6, 0.18730736), (9, 0.070576936)]
#
# --------------
#
# Document  569
#
# Document topics: [(7, 0.9954765)]
#
# --------------
#
# Document  570
#
# Document topics: [(0, 0.08762207), (1, 0.16036671), (4, 0.031832967), (6, 0.09012785), (7, 0.58865315), (9, 0.04097739)]
#
# --------------
#
# Document  571
#
# Document topics: [(1, 0.7085146), (7, 0.27898225)]
#
# --------------
#
# Document  572
#
# Document topics: [(0, 0.9756709)]
#
# --------------
#
# Document  573
#
# Document topics: [(0, 0.9964136)]
#
# --------------
# Document  574
#
# Document topics: [(3, 0.2392788), (4, 0.078471005), (7, 0.623646), (9, 0.056728717)]
#
# --------------
#
# Document  575
#
# Document topics: [(6, 0.98474246)]
#
# --------------
#
# Document  576
#
# Document topics: [(0, 0.15075551), (5, 0.27225727), (6, 0.3372832), (7, 0.058668222), (9, 0.17944813)]
#
# --------------
#
# Document  577
#
# Document topics: [(0, 0.2577891), (4, 0.57765055), (6, 0.16309868)]
#
# --------------
#
# Document  578
#
# Document topics: [(0, 0.08967374), (2, 0.16301502), (4, 0.22454111), (6, 0.26123396), (8, 0.25859436)]
#
# --------------
#
# Document  579
#
# Document topics: [(0, 0.21050927), (2, 0.2839743), (4, 0.035059277), (6, 0.16756855), (7, 0.1053056), (9, 0.19677633)]
#
# --------------
#
# Document  580
#
# Document topics: [(0, 0.16532584), (2, 0.32999593), (3, 0.10891083), (4, 0.01100324), (6, 0.20881844), (7, 0.07003412), (8, 0.013741134), (9, 0.091945924)]
#
# --------------
#
# Document  581
#
# Document topics: [(0, 0.22030123), (3, 0.4694393), (6, 0.06974686), (7, 0.23689736)]
#
# --------------
#
# Document  582
#
# Document topics: [(4, 0.5786749), (6, 0.04612486), (7, 0.37281868)]
#
# --------------
#
# Document  583
#
# Document topics: [(0, 0.17516911), (6, 0.82216376)]
#
# --------------
#
# Document  584
#
# Document topics: [(0, 0.0770194), (1, 0.38912565), (2, 0.16330683), (3, 0.1004671), (4, 0.026959749), (6, 0.11089827), (7, 0.13170294)]
#
# --------------
#
# Document  585
#
# Document topics: [(4, 0.64009476), (7, 0.35517067)]
#
# --------------
#
# Document  586
#
# Document topics: [(0, 0.15293707), (6, 0.7429752), (9, 0.1015041)]
#
# --------------
#
# Document  587
#
# Document topics: [(3, 0.22346577), (5, 0.32654163), (9, 0.43509585)]
#
# --------------
#
# Document  588
#
# Document topics: [(3, 0.7271086), (9, 0.27053794)]
#
# --------------
#
# Document  589
#
# Document topics: [(3, 0.35566825), (6, 0.47555625), (7, 0.09511485), (9, 0.07208555)]
#
# --------------
#
# Document  590
#
# Document topics: [(0, 0.16951269), (3, 0.010807907), (6, 0.042466637), (7, 0.033153255), (8, 0.68614125), (9, 0.05685421)]
#
# --------------
#
# Document  591
#
# Document topics: [(6, 0.08642601), (9, 0.8957937)]
#
# --------------
#
# Document  592
#
# Document topics: [(7, 0.99256045)]
#
# --------------
#
# Document  593
#
# Document topics: [(0, 0.16691998), (6, 0.071760595), (7, 0.63197863), (9, 0.128157)]
#
# --------------
#
# Document  594
#
# Document topics: [(6, 0.74283355), (7, 0.2546581)]
#
# --------------
#
# Document  595
#
# Document topics: [(0, 0.037670214), (4, 0.67269963), (9, 0.28737158)]
#
# --------------
#
# Document  596
#
# Document topics: [(0, 0.16637173), (4, 0.47765878), (6, 0.06849948), (7, 0.17824568), (9, 0.10870389)]
#
# --------------
#
# Document  597
#
# Document topics: [(9, 0.99196297)]
#
# --------------
#
# Document  598
#
# Document topics: [(0, 0.043464992), (4, 0.16170177), (7, 0.7932088)]
#
# --------------
#
# Document  599
#
# Document topics: [(0, 0.15125692), (6, 0.17135523), (7, 0.070009716), (8, 0.5617952), (9, 0.044867467)]
#
# --------------
#
# Document  600
#
# Document topics: [(9, 0.9945108)]
#
# --------------
#
# Document  601
#
# Document topics: [(0, 0.03485599), (1, 0.4300431), (3, 0.054796435), (6, 0.019165399), (7, 0.45968947)]
#
# --------------
#
# Document  602
#
# Document topics: [(0, 0.41200712), (4, 0.09310158), (6, 0.17136434), (8, 0.29566512), (9, 0.026468724)]
#
# --------------
#
# Document  603
#
# Document topics: [(0, 0.06640057), (4, 0.024830703), (5, 0.22532457), (6, 0.026430963), (7, 0.6553573)]
#
# --------------
#
# Document  604
#
# Document topics: [(0, 0.28383425), (3, 0.014006816), (6, 0.1389153), (7, 0.049015395), (8, 0.46872437), (9, 0.044685706)]
#
# --------------
#
# Document  605
#
# Document topics: [(4, 0.9735246)]
#
# --------------
#
# Document  606
#
# Document topics: [(0, 0.8342627), (6, 0.09129666), (7, 0.07241701)]
#
# --------------
#
# Document  607
#
# Document topics: [(4, 0.42949665), (7, 0.05696882), (9, 0.5095336)]
#
# --------------
#
# Document  608
#
# Document topics: [(4, 0.8554618), (6, 0.12402138)]
#
# --------------
#
# Document  609
#
# Document topics: [(6, 0.5218647), (7, 0.26872116), (9, 0.20743077)]
#
# --------------
#
# Document  610
#
# Document topics: [(0, 0.0932786), (6, 0.8686318), (9, 0.03765763)]
#
# --------------
#
# Document  611
#
# Document topics: [(0, 0.2824838), (3, 0.6476155), (7, 0.06455599)]
#
# --------------
#
# Document  612
#
# Document topics: [(0, 0.047701392), (6, 0.8931578), (9, 0.057157356)]
#
# --------------
#
# Document  613
#
# Document topics: [(0, 0.03048929), (3, 0.65206367), (4, 0.10753245), (6, 0.12362518), (7, 0.0673439), (9, 0.018319404)]
#
# --------------
#
# Document  614
#
# Document topics: [(4, 0.68391854), (7, 0.27162763), (9, 0.04183144)]
#
# --------------
#
# Document  615
#
# Document topics: [(0, 0.14568947), (6, 0.6036297), (7, 0.23512274)]
#
# --------------
#
# Document  616
#
# Document topics: [(7, 0.121967174), (9, 0.87403196)]
#
# --------------
#
# Document  617
#
# Document topics: [(0, 0.06773715), (1, 0.38604587), (4, 0.042955622), (5, 0.04407496), (6, 0.17946872), (7, 0.27877852)]
#
# --------------
#
# Document  618
#
# Document topics: [(0, 0.42403254), (2, 0.17554283), (5, 0.16552557), (6, 0.122911595), (9, 0.11010733)]
#
# --------------
#
# Document  619
#
# Document topics: [(4, 0.5756116), (6, 0.041074116), (9, 0.3783488)]
#
# --------------
#
# Document  620
#
# Document topics: [(0, 0.26252684), (1, 0.30574474), (6, 0.1661274), (7, 0.077203654), (9, 0.18765318)]
#
# --------------

# %%
df2 = pd.DataFrame(topic_list,columns=['Topic'])
df3 = pd.DataFrame(content_list,columns=['Content'])
df4 =pd.DataFrame(tp_words,columns=['Topic Words'])
df5 =pd.DataFrame(content_num,columns=['Article Number'])
df1=pd.DataFrame(prob_list,columns=['Probability'])

df1 = df1.assign(df2=df2.values)
df1 = df1.assign(df3=df3.values)
df1=df1.assign(df4=df4.values)
myTable = df1.assign(df5=df5.values)
myTable.columns=['Probability','Topic','Cotent','Topic Words','Article Number']

# %%
myTable
# Out:
#       Probability  Topic                                             Cotent  \
# 0        0.467563      6  Former Commonwealth Bank director and risk com...
# 1        0.529968      7  Former Commonwealth Bank director and risk com...
# 2        0.096982      0  IAG says it is still in talks with its group g...
# 3        0.733315      3  IAG says it is still in talks with its group g...
# 4        0.090112      6  IAG says it is still in talks with its group g...
# 5        0.075394      7  IAG says it is still in talks with its group g...
# 6        0.303491      1  by Michael Pelly \n\nIt's reporting season for...
# 7        0.318525      3  by Michael Pelly \n\nIt's reporting season for...
# 8        0.208625      6  by Michael Pelly \n\nIt's reporting season for...
# 9        0.167152      9  by Michael Pelly \n\nIt's reporting season for...
# 10       0.084411      0  Victoria's Independent Broad-Based Anti-Corrup...
# 11       0.823928      6  Victoria's Independent Broad-Based Anti-Corrup...
# 12       0.090111      9  Victoria's Independent Broad-Based Anti-Corrup...
# 13       0.995672      7  Funeral insurance company Let’s Insure, a trad...
# 14       0.590959      7  Staff working in a Sydney call centre selling ...
# 15       0.406879      9  Staff working in a Sydney call centre selling ...
# 16       0.787713      4  A Tasmanian farmer who lost everything says th...
# 17       0.207495      6  A Tasmanian farmer who lost everything says th...
# 18       0.995383      0  The Reserve Bank may be forced to hold interes...
# 19       0.038667      0  A company accused of playing on the significan...
# 20       0.033496      2  A company accused of playing on the significan...
# 21       0.253288      3  A company accused of playing on the significan...
# 22       0.045194      4  A company accused of playing on the significan...
# 23       0.184276      7  A company accused of playing on the significan...
# 24       0.443788      9  A company accused of playing on the significan...
# 25       0.223329      0  Australia's biggest investment bank, Macquarie...
# 26       0.120347      4  Australia's biggest investment bank, Macquarie...
# 27       0.139075      6  Australia's biggest investment bank, Macquarie...
# 28       0.437977      8  Australia's biggest investment bank, Macquarie...
# 29       0.076844      9  Australia's biggest investment bank, Macquarie...
# ...           ...    ...                                                ...
# 2051     0.123625      6  Westpac AmEx Altitude Black Bundle - up to 120...
# 2052     0.067344      7  Westpac AmEx Altitude Black Bundle - up to 120...
# 2053     0.018319      9  Westpac AmEx Altitude Black Bundle - up to 120...
# 2054     0.683919      4  Former Tasmanian cattle and lamb farmer Michae...
# 2055     0.271628      7  Former Tasmanian cattle and lamb farmer Michae...
# 2056     0.041831      9  Former Tasmanian cattle and lamb farmer Michae...
# 2057     0.145689      0  The financial services royal commission contin...
# 2058     0.603630      6  The financial services royal commission contin...
# 2059     0.235123      7  The financial services royal commission contin...
# 2060     0.121967      7  A bank manager who had a three-way conflict ov...
# 2061     0.874032      9  A bank manager who had a three-way conflict ov...
# 2062     0.067737      0  Queensland grazier Deborah Smith says she felt...
# 2063     0.386046      1  Queensland grazier Deborah Smith says she felt...
# 2064     0.042956      4  Queensland grazier Deborah Smith says she felt...
# 2065     0.044075      5  Queensland grazier Deborah Smith says she felt...
# 2066     0.179469      6  Queensland grazier Deborah Smith says she felt...
# 2067     0.278779      7  Queensland grazier Deborah Smith says she felt...
# 2068     0.424033      0  Regulators will target the use of self-managed...
# 2069     0.175543      2  Regulators will target the use of self-managed...
# 2070     0.165526      5  Regulators will target the use of self-managed...
# 2071     0.122912      6  Regulators will target the use of self-managed...
# 2072     0.110107      9  Regulators will target the use of self-managed...
# 2073     0.575612      4  Cattle farmer Wendy Brauer is still sad and ma...
# 2074     0.041074      6  Cattle farmer Wendy Brauer is still sad and ma...
# 2075     0.378349      9  Cattle farmer Wendy Brauer is still sad and ma...
# 2076     0.262527      0  We’re apathetic about super, until we’re not. ...
# 2077     0.305745      1  We’re apathetic about super, until we’re not. ...
# 2078     0.166127      6  We’re apathetic about super, until we’re not. ...
# 2079     0.077204      7  We’re apathetic about super, until we’re not. ...
# 2080     0.187653      9  We’re apathetic about super, until we’re not. ...
#
#                                             Topic Words  Article Number
# 0     bankwest ruddy marika bank insurance subsectio...               0
# 1     anz ruddy insure funeral bank insurance aborig...               0
# 2        cba banks mortgage loan bank sales home growth               1
# 3     aboriginal acbf funeral indigenous walsh insur...               1
# 4     bankwest ruddy marika bank insurance subsectio...               1
# 5     anz ruddy insure funeral bank insurance aborig...               1
# 6        c growth market anz katter dover prices smiths               2
# 7     aboriginal acbf funeral indigenous walsh insur...               2
# 8     bankwest ruddy marika bank insurance subsectio...               2
# 9     subsections show funeral text orr insurance ab...               2
# 10       cba banks mortgage loan bank sales home growth               3
# 11    bankwest ruddy marika bank insurance subsectio...               3
# 12    subsections show funeral text orr insurance ab...               3
# 13    anz ruddy insure funeral bank insurance aborig...               4
# 14    anz ruddy insure funeral bank insurance aborig...               5
# 15    subsections show funeral text orr insurance ab...               5
# 16    anz banks bank landmark customers dover debt asic               6
# 17    bankwest ruddy marika bank insurance subsectio...               6
# 18       cba banks mortgage loan bank sales home growth               7
# 19       cba banks mortgage loan bank sales home growth               8
# 20    evans funeral hirst dixon aboriginal acbf advi...               8
# 21    aboriginal acbf funeral indigenous walsh insur...               8
# 22    anz banks bank landmark customers dover debt asic               8
# 23    anz ruddy insure funeral bank insurance aborig...               8
# 24    subsections show funeral text orr insurance ab...               8
# 25       cba banks mortgage loan bank sales home growth               9
# 26    anz banks bank landmark customers dover debt asic               9
# 27    bankwest ruddy marika bank insurance subsectio...               9
# 28    brokers rural commissions bank anz landmark lo...               9
# 29    subsections show funeral text orr insurance ab...               9
# ...                                                 ...             ...
# 2051  bankwest ruddy marika bank insurance subsectio...             612
# 2052  anz ruddy insure funeral bank insurance aborig...             612
# 2053  subsections show funeral text orr insurance ab...             612
# 2054  anz banks bank landmark customers dover debt asic             613
# 2055  anz ruddy insure funeral bank insurance aborig...             613
# 2056  subsections show funeral text orr insurance ab...             613
# 2057     cba banks mortgage loan bank sales home growth             614
# 2058  bankwest ruddy marika bank insurance subsectio...             614
# 2059  anz ruddy insure funeral bank insurance aborig...             614
# 2060  anz ruddy insure funeral bank insurance aborig...             615
# 2061  subsections show funeral text orr insurance ab...             615
# 2062     cba banks mortgage loan bank sales home growth             616
# 2063     c growth market anz katter dover prices smiths             616
# 2064  anz banks bank landmark customers dover debt asic             616
# 2065  cba insurance wealth cattle smith heard manage...             616
# 2066  bankwest ruddy marika bank insurance subsectio...             616
# 2067  anz ruddy insure funeral bank insurance aborig...             616
# 2068     cba banks mortgage loan bank sales home growth             617
# 2069  evans funeral hirst dixon aboriginal acbf advi...             617
# 2070  cba insurance wealth cattle smith heard manage...             617
# 2071  bankwest ruddy marika bank insurance subsectio...             617
# 2072  subsections show funeral text orr insurance ab...             617
# 2073  anz banks bank landmark customers dover debt asic             618
# 2074  bankwest ruddy marika bank insurance subsectio...             618
# 2075  subsections show funeral text orr insurance ab...             618
# 2076     cba banks mortgage loan bank sales home growth             619
# 2077     c growth market anz katter dover prices smiths             619
# 2078  bankwest ruddy marika bank insurance subsectio...             619
# 2079  anz ruddy insure funeral bank insurance aborig...             619
# 2080  subsections show funeral text orr insurance ab...             619
#
# [2081 rows x 5 columns]

# %%
sortedTable=myTable.sort_values(by=['Topic', 'Probability'],ascending=[True,False])

# %%
sortedTable
# Out:
#       Probability  Topic                                             Cotent  \
# 465      0.996538      0  New homes sales fell 4.4 per cent in May to be...
# 1910     0.996414      0  FULL TEXT\n\n\n\nInvestors finished the financ...
# 18       0.995383      0  The Reserve Bank may be forced to hold interes...
# 1292     0.995212      0  Brokers experiencing longer turnaround times m...
# 886      0.995054      0  Brokers and bankers are often portrayed as but...
# 979      0.993999      0  ASIC has found that a “large number” of SMSF a...
# 1717     0.990999      0  It means when the royal commission makes its r...
# 606      0.988605      0  (30 June 2018, AFR, p11, by  Larry Schlesinger...
# 518      0.988156      0  The housing market could take a hit from the r...
# 699      0.987835      0  The first farmer takes the stand at the royal ...
# 1232     0.985935      0    The banking royal commission has dropped nat...
# 726      0.984209      0  The banking Royal Commission is having an impa...
# 118      0.980431      0  Our biggest trading partner China appears to h...
# 1440     0.979869      0  If you have a mortgage with one of the big-fou...
# 1909     0.975671      0  Indigenous Australians have given damning evid...
# 1169     0.968961      0  At the financial services royal commission tod...
# 304      0.956620      0  Malcolm Turnbull has accused Labor of risking ...
# 1381     0.950127      0  The Australian mortgage industry is on track f...
# 885      0.943742      0  The royal commission will deliver its recommen...
# 401      0.941814      0  Commonwealth Bank to Demerge Advice Businesses...
# 323      0.935706      0  Bank fees can chew up as much as a fifth of th...
# 1788     0.924527      0  The big banks are getting ahead of any recomme...
# 1212     0.910082      0  So toxic has much of Australia’s superannuatio...
# 1830     0.906674      0  Leading national firm Clayton Utz is on the ve...
# 1366     0.901625      0  In 2014, the  suggested to banks that they thi...
# 1805     0.892045      0  Commissioner Kenneth Hayne has shot back at cr...
# 779      0.889697      0  In a move which signals the likelihood of the ...
# 1106     0.887952      0  Australian new housing sales fell for a fifth ...
# 1811     0.883101      0  Some Landmark agribusiness customers may have ...
# 599      0.860640      0  Tighter credit and changing lending policies a...
# ...           ...    ...                                                ...
# 1358     0.037078      9  EXAMPLES of poor lending practices of Rural Ba...
# 1291     0.036447      9  Australian shares ended the financial year on ...
# 1428     0.036201      9  – With AAP \n 1. Nurse’s home searched by poli...
# 1561     0.035853      9  New research shows that first home buyers are ...
# 1236     0.035626      9  Medical device company Cochlear and blood prod...
# 602      0.035565      9  Tighter credit and changing lending policies a...
# 1800     0.035010      9  Australia's main rural lenders face numerous f...
# 597      0.034431      9  RBA unveils cash rate decision for July 2018 —...
# 122      0.033008      9  Bill Shorten's by holding Braddon and Longman ...
# 1060     0.031778      9  Share close: Market in retreat with banks down...
# 1397     0.031584      9  The ANZ bank gave a couple one day to be off t...
# 878      0.031322      9  Related Story: \n       As it happened: 'No em...
# 1565     0.031025      9  The Commonwealth Bank's demerger of its wealth...
# 1725     0.028441      9  The banking Royal Commission, for the past thr...
# 470      0.028355      9  WATCH YOUR WORDS Legislation restricting forei...
# 538      0.027824      9  Top economists are turning more bearish on the...
# 1832     0.027800      9  Leading national firm Clayton Utz is on the ve...
# 1179     0.026989      9  Financial advice CBA is forcing investors into...
# 1339     0.026590      9  SHARE OPEN First day of the new Financial Year...
# 2015     0.026469      9  The RBA hasn’t moved official interest rates s...
# 1497     0.025490      9  If you’re a first home buyer looking to purcha...
# 1368     0.024026      9  In 2014, the  suggested to banks that they thi...
# 1271     0.023931      9  It’s clear the Finance Royal Commission has sc...
# 1392     0.022062      9  The head of the FBAA has urged the ABC to do m...
# 1643     0.020344      9  The Australian sharemarket has closed the quar...
# 1033     0.020050      9  This week was all about tax, or at least that'...
# 2053     0.018319      9  Westpac AmEx Altitude Black Bundle - up to 120...
# 605      0.015993      9  Bendigo and Adelaide Bank has admitted to a st...
# 76       0.012601      9  The Financial Services Royal Commission has ex...
# 360      0.011114      9  Banking Royal Commission runs out of time to q...
#
#                                             Topic Words  Article Number
# 465      cba banks mortgage loan bank sales home growth             145
# 1910     cba banks mortgage loan bank sales home growth             572
# 18       cba banks mortgage loan bank sales home growth               7
# 1292     cba banks mortgage loan bank sales home growth             391
# 886      cba banks mortgage loan bank sales home growth             273
# 979      cba banks mortgage loan bank sales home growth             300
# 1717     cba banks mortgage loan bank sales home growth             515
# 606      cba banks mortgage loan bank sales home growth             187
# 518      cba banks mortgage loan bank sales home growth             160
# 699      cba banks mortgage loan bank sales home growth             216
# 1232     cba banks mortgage loan bank sales home growth             375
# 726      cba banks mortgage loan bank sales home growth             224
# 118      cba banks mortgage loan bank sales home growth              37
# 1440     cba banks mortgage loan bank sales home growth             435
# 1909     cba banks mortgage loan bank sales home growth             571
# 1169     cba banks mortgage loan bank sales home growth             353
# 304      cba banks mortgage loan bank sales home growth              98
# 1381     cba banks mortgage loan bank sales home growth             418
# 885      cba banks mortgage loan bank sales home growth             272
# 401      cba banks mortgage loan bank sales home growth             126
# 323      cba banks mortgage loan bank sales home growth             104
# 1788     cba banks mortgage loan bank sales home growth             538
# 1212     cba banks mortgage loan bank sales home growth             369
# 1830     cba banks mortgage loan bank sales home growth             550
# 1366     cba banks mortgage loan bank sales home growth             413
# 1805     cba banks mortgage loan bank sales home growth             543
# 779      cba banks mortgage loan bank sales home growth             238
# 1106     cba banks mortgage loan bank sales home growth             337
# 1811     cba banks mortgage loan bank sales home growth             545
# 599      cba banks mortgage loan bank sales home growth             185
# ...                                                 ...             ...
# 1358  subsections show funeral text orr insurance ab...             411
# 1291  subsections show funeral text orr insurance ab...             390
# 1428  subsections show funeral text orr insurance ab...             430
# 1561  subsections show funeral text orr insurance ab...             470
# 1236  subsections show funeral text orr insurance ab...             376
# 602   subsections show funeral text orr insurance ab...             185
# 1800  subsections show funeral text orr insurance ab...             541
# 597   subsections show funeral text orr insurance ab...             183
# 122   subsections show funeral text orr insurance ab...              38
# 1060  subsections show funeral text orr insurance ab...             321
# 1397  subsections show funeral text orr insurance ab...             423
# 878   subsections show funeral text orr insurance ab...             269
# 1565  subsections show funeral text orr insurance ab...             471
# 1725  subsections show funeral text orr insurance ab...             518
# 470   subsections show funeral text orr insurance ab...             146
# 538   subsections show funeral text orr insurance ab...             166
# 1832  subsections show funeral text orr insurance ab...             550
# 1179  subsections show funeral text orr insurance ab...             356
# 1339  subsections show funeral text orr insurance ab...             405
# 2015  subsections show funeral text orr insurance ab...             601
# 1497  subsections show funeral text orr insurance ab...             451
# 1368  subsections show funeral text orr insurance ab...             413
# 1271  subsections show funeral text orr insurance ab...             385
# 1392  subsections show funeral text orr insurance ab...             422
# 1643  subsections show funeral text orr insurance ab...             493
# 1033  subsections show funeral text orr insurance ab...             314
# 2053  subsections show funeral text orr insurance ab...             612
# 605   subsections show funeral text orr insurance ab...             186
# 76    subsections show funeral text orr insurance ab...              24
# 360   subsections show funeral text orr insurance ab...             113
#
# [2081 rows x 5 columns]

# %%
def KeySentence(article_number,key_words):

    
    article=data[article_number]
    i=0;
    j=0;
    sentenceEnders = re.compile('[.!?\n]')
    sentenceList = []
    sentenceList = sentenceEnders.split(article)
    newList=[]
    LabeledSentence1 = gensim.models.doc2vec.TaggedDocument
    #print(article)
    #print(sentenceList)
    all_clean_sentence=[]
    for s in sentenceList:           
  
        #Pre-processing
        processed_sentence = review_to_wordlist(s)
        
        
        # add tokens to list
        if processed_sentence:
            all_clean_sentence.append(LabeledSentence1(processed_sentence,[j]))
        
            j=j+1
            newList.append(sentenceList[i])
        i=i+1

    d2v_model = Doc2Vec(all_clean_sentence, vector_size = 1000, min_count = 1, workers=7, dm = 1, 
                    alpha=0.025, min_alpha=0.001)
    d2v_model.train(all_clean_sentence, total_examples=d2v_model.corpus_count, epochs=100, start_alpha=0.002, end_alpha=-0.016)
    tokens = key_words.split()
    new_vector = d2v_model.infer_vector(tokens)
    sims = d2v_model.docvecs.most_similar([new_vector])
    
    #print(all_clean_sentence)
    #print(sentenceList)
    #print(sims[0][0])
    return all_clean_sentence[sims[0][0]],newList[sims[0][0]]

# %%
Key_sentence=list()
my_words=list()
a_number=list()
for i in range(0,10):
    df=sortedTable.loc[sortedTable['Topic'] == i]
    df.reset_index()
    article_number=df.iloc[0,-1]
    key_words=df.iloc[0,-2]
    a1,a2=KeySentence(article_number,key_words)
    Key_sentence.append(a2)
    my_words.append(key_words)
    a_number.append(article_number)
    
    print("Topic",i+1,":\n")
    print("Key Words:",key_words,"\n")
    print("Key Sentences:",a1,"\n",a2,"\n")
    print("-------------------------------------------------------------------------------------------------------\n")
# Out:
# /Users/shengyuan/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# Topic 1 :
#
# Key Words: cba banks mortgage loan bank sales home growth
#
# Key Sentences: TaggedDocument(['beyond', 'temporary', 'lift', 'expect', 'downturn', 'detached', 'house', 'building', 'properly', 'take', 'root', 'house', 'sales', 'appear', 'providing', 'early', 'indication', 'occurring'], [25])
#  "Beyond that temporary lift, we expect the downturn in detached house building to properly take root in 2019 – and house sales appear to be providing a very early indication of this occurring
#
# -------------------------------------------------------------------------------------------------------
#
# Topic 2 :
#
# Key Words: c growth market anz katter dover prices smiths
#
# Key Sentences: TaggedDocument(['comes', 'banking', 'delay', 'hearing', 'cases', 'related', 'natural', 'disaster', 'finance', 'devote', 'time', 'farm', 'debt'], [0])
#  It comes as the banking royal commission will delay hearing cases related to natural disaster finance, to devote more time to farm debt
#
# -------------------------------------------------------------------------------------------------------
#
# Topic 3 :
#
# Key Words: evans funeral hirst dixon aboriginal acbf advice parkinson
#
# Key Sentences: TaggedDocument(['aside', 'like', 'hear', 'sinc', 'views', 'banking'], [0])
#  As an aside, I’d like to hear Sinc’s views about the banking Royal Commission
#
# -------------------------------------------------------------------------------------------------------
#
# Topic 4 :
#
# Key Words: aboriginal acbf funeral indigenous walsh insurance anz steinberg
#
# Key Sentences: TaggedDocument(['addition', 'dramatic', 'change', 'proportion', 'internaional', 'promotions', 'lateral', 'hires', 'rewritten', 'rulebook', 'making', 'partner', 'law', 'firm'], [3])
#  In addition, a dramatic change in the proportion of internaional promotions and lateral hires has rewritten the rulebook for making partner in a law firm
#
# -------------------------------------------------------------------------------------------------------
#
# Topic 5 :
#
# Key Words: anz banks bank landmark customers dover debt asic
#
# Key Sentences: TaggedDocument(['gartmann', 'said', 'left', 'company', 'denied', 'systemic', 'problems', 'despite', 'internal', 'report', 'kpmg', 'report', 'recommending', 'major', 'structural', 'changes', 'rural', 'bank', 'managing', 'customers', 'loans'], [13])
#  While Ms Gartmann said they had left the company, she denied there were systemic problems, despite an internal report and a KPMG report recommending major structural changes at Rural Bank when managing customers and loans
#
# -------------------------------------------------------------------------------------------------------
#
# Topic 6 :
#
# Key Words: cba insurance wealth cattle smith heard management video
#
# Key Sentences: TaggedDocument(['banking', 'heard', 'bank', 'manager', 'rewarded', 'trip', 'hayman', 'island', 'later', 'found', 'inflated', 'property', 'valuations'], [0])
#  The banking royal commission has heard a bank manager who was rewarded with a trip to Hayman Island was later found to have inflated property valuations
#
# -------------------------------------------------------------------------------------------------------
#
# Topic 7 :
#
# Key Words: bankwest ruddy marika bank insurance subsections loan property
#
# Key Sentences: TaggedDocument(['related', 'content', 'hey', 'banks', 'reputation', 'building', 'campaigns', 'please', 'opinion', 'feet', 'tall', 'wins', 'creative', 'account', 'white', 'goods', 'company', 'e', 'news'], [31])
#     Related Content      Hey banks - no reputation building campaigns, please  Opinion       10 Feet Tall wins creative account for white goods company E&S  News
#
# -------------------------------------------------------------------------------------------------------
#
# Topic 8 :
#
# Key Words: anz ruddy insure funeral bank insurance aboriginal account
#
# Key Sentences: TaggedDocument(['another', 'competition', 'let', 'insure', 'sailors', 'sales', 'incentive', 'sales', 'staff', 'offered', 'two', 'days', 'paid', 'leave', 'go', 'four', 'night', 'cruise', 'sydney', 'sunshine', 'coast', 'p', 'pacific', 'would', 'get', 'luxury', 'ocean', 'view', 'cabin', 'meals', 'silver', 'service', 'restaurants'], [13])
#  In another competition, "Let's Insure Sailors' Sales Incentive", sales staff were offered two days of paid leave to go on a four-night cruise from Sydney to the Sunshine Coast on P&O's Pacific where they would get a "luxury ocean view" cabin and all meals in "silver-service" restaurants
#
# -------------------------------------------------------------------------------------------------------
#
# Topic 9 :
#
# Key Words: brokers rural commissions bank anz landmark loan customers
#
# Key Sentences: TaggedDocument(['external', 'link', 'banking', 'blog'], [2])
#   External Link: Banking royal commission blog
#
# -------------------------------------------------------------------------------------------------------
#
# Topic 10 :
#
# Key Words: subsections show funeral text orr insurance aboriginal anz
#
# Key Sentences: TaggedDocument(['proceeding', 'listed', 'directions', 'hearing', 'federal', 'court', 'sydney', 'july'], [16])
#  The proceeding is listed for a directions hearing in the Federal Court in Sydney on July 27
#
# -------------------------------------------------------------------------------------------------------

# %%
finalTable = pd.DataFrame(a_number,columns=['Article Number'])
df6 = pd.DataFrame(my_words,columns=['words'])
df7 =pd.DataFrame(Key_sentence,columns=['Key_sentence'])


finalTable = finalTable.assign(df6=df6.values)
finalTable =finalTable.assign(df7=df7.values)

finalTable.columns=['Article Number','Words','Key_sentence']
finalTable
# Out:
#    Article Number                                              Words  \
# 0             145     cba banks mortgage loan bank sales home growth
# 1             458     c growth market anz katter dover prices smiths
# 2             475  evans funeral hirst dixon aboriginal acbf advi...
# 3             354  aboriginal acbf funeral indigenous walsh insur...
# 4             373  anz banks bank landmark customers dover debt asic
# 5             407  cba insurance wealth cattle smith heard manage...
# 6              47  bankwest ruddy marika bank insurance subsectio...
# 7             277  anz ruddy insure funeral bank insurance aborig...
# 8             526  brokers rural commissions bank anz landmark lo...
# 9              95  subsections show funeral text orr insurance ab...
#
#                                         Key_sentence
# 0  "Beyond that temporary lift, we expect the dow...
# 1  It comes as the banking royal commission will ...
# 2  As an aside, I’d like to hear Sinc’s views abo...
# 3  In addition, a dramatic change in the proporti...
# 4  While Ms Gartmann said they had left the compa...
# 5  The banking royal commission has heard a bank ...
# 6     Related Content      Hey banks - no reputat...
# 7  In another competition, "Let's Insure Sailors'...
# 8       External Link: Banking royal commission blog
# 9  The proceeding is listed for a directions hear...
